# %% [markdown]
# # Dataset Spotlight: How ISIS Uses Twitter
#
# ### Description
#
# This dataset includes 17,000 tweets from 100+ pro-ISIS fanboys from all over the world since the November 2015 Paris Attacks.
#
# The columns describe the following:
#
# **Name**
# - Username
# - Description
# - Location
# - Number of followers at the time the tweet was downloaded
# - Number of statuses by the user when the tweet was downloaded
# - Date and timestamp of the tweet
# - The tweet itself
#
#
# #### Based on this data, these are some examples for deriving insights and analysis:
#
# - **Social Network Cluster Analysis:** Who are the major players in the pro-ISIS twitter network? Ideally, we would like this visualized via a cluster network with the biggest influencers scaled larger than smaller influencers.
# - **Keyword Analysis:** Which keywords derived from the name, username, description, location, and tweets were the most commonly used by ISIS fanboys? Examples include: "baqiyah", "dabiq", "wilayat", "amaq"
# - **Data Categorization of Links:** Which websites are pro-ISIS fanboys linking to? Categories include: Mainstream Media, Altermedia, Jihadist Websites, Image Upload, Video Upload,
# - **Sentiment Analysis:** Which clergy do pro-ISIS fanboys quote the most and which ones do they hate the most? Search the tweets for names of prominent clergy and classify the tweet as positive, negative, or neutral and if negative, include the reasons why. Examples of clergy they like the most: "Anwar Awlaki", "Ahmad Jibril", "Ibn Taymiyyah", "Abdul Wahhab". Examples of clergy that they hate the most: "Hamza Yusuf", "Suhaib Webb", "Yaser Qadhi", "Nouman Ali Khan", "Yaqoubi".
# - **Timeline View:** Visualize all the tweets over a timeline and identify peak moments
#
#
# *Source:*
# - http://blog.kaggle.com/2016/06/03/dataset-spotlight-how-isis-uses-twitter/
# - https://www.kaggle.com/kzaman/how-isis-uses-twitter
#
# *Sources on network analysis*
# - https://www.slideshare.net/koorukuroo/network-analysis-with-networkx-fundamentals-of-network-theory1
# - https://www.slideshare.net/BenjaminBengfort/social-network-analysis-with-python
# - https://www.datacamp.com/courses/network-analysis-in-python-part-1

# %%
import pandas as pd

# %%
# import dataset as pandas dataframe

df = pd.read_csv('Twitter_ISIS_data/how-isis-uses-twitter/tweets.csv')
df
# Out:
#                      name         username  \
# 0           GunsandCoffee  GunsandCoffee70
# 1           GunsandCoffee  GunsandCoffee70
# 2           GunsandCoffee  GunsandCoffee70
# 3           GunsandCoffee  GunsandCoffee70
# 4           GunsandCoffee  GunsandCoffee70
# 5           GunsandCoffee  GunsandCoffee70
# 6           GunsandCoffee  GunsandCoffee70
# 7           GunsandCoffee  GunsandCoffee70
# 8           GunsandCoffee  GunsandCoffee70
# 9           GunsandCoffee  GunsandCoffee70
# 10          GunsandCoffee  GunsandCoffee70
# 11          GunsandCoffee  GunsandCoffee70
# 12          GunsandCoffee  GunsandCoffee70
# 13          GunsandCoffee  GunsandCoffee70
# 14          GunsandCoffee  GunsandCoffee70
# 15          GunsandCoffee  GunsandCoffee70
# 16          GunsandCoffee  GunsandCoffee70
# 17          GunsandCoffee  GunsandCoffee70
# 18          GunsandCoffee  GunsandCoffee70
# 19          GunsandCoffee  GunsandCoffee70
# 20          GunsandCoffee  GunsandCoffee70
# 21          GunsandCoffee  GunsandCoffee70
# 22          GunsandCoffee  GunsandCoffee70
# 23          GunsandCoffee  GunsandCoffee70
# 24          GunsandCoffee  GunsandCoffee70
# 25          GunsandCoffee  GunsandCoffee70
# 26          GunsandCoffee  GunsandCoffee70
# 27          GunsandCoffee  GunsandCoffee70
# 28          GunsandCoffee  GunsandCoffee70
# 29     Abu Layth Al Hindi  AbuLaythAlHindi
# ...                   ...              ...
# 17380                  ☝️       melvynlion
# 17381           N i d a l      Nidalgazaui
# 17382         Anaksabil97          nvor85j
# 17383           N i d a l      Nidalgazaui
# 17384        Mountain Man   Mountainjjoool
# 17385         Anaksabil97          nvor85j
# 17386           N i d a l      Nidalgazaui
# 17387        كتكات كوكونت    Uncle_SamCoco
# 17388         Anaksabil97          nvor85j
# 17389        كتكات كوكونت    Uncle_SamCoco
# 17390         Anaksabil97          nvor85j
# 17391        كتكات كوكونت    Uncle_SamCoco
# 17392        كتكات كوكونت    Uncle_SamCoco
# 17393    one who believes           ro34th
# 17394      Musa Al-Ansari        lNSlDEWAR
# 17395        كتكات كوكونت    Uncle_SamCoco
# 17396        كتكات كوكونت    Uncle_SamCoco
# 17397        كتكات كوكونت    Uncle_SamCoco
# 17398        كتكات كوكونت    Uncle_SamCoco
# 17399        كتكات كوكونت    Uncle_SamCoco
# 17400        Mountain Man   Mountainjjoool
# 17401        Mountain Man   Mountainjjoool
# 17402        كتكات كوكونت    Uncle_SamCoco
# 17403         Anaksabil97          nvor85j
# 17404        كتكات كوكونت    Uncle_SamCoco
# 17405         Anaksabil97          nvor85j
# 17406         Anaksabil97          nvor85j
# 17407         Anaksabil97          nvor85j
# 17408         Anaksabil97          nvor85j
# 17409    one who believes           ro34th
#
#                                              description           location  \
# 0           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 1           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 2           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 3           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 4           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 5           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 6           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 7           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 8           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 9           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 10          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 11          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 12          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 13          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 14          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 15          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 16          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 17          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 18          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 19          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 20          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 21          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 22          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 23          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 24          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 25          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 26          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 27          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 28          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 29     Kik: abulayth2014. Ex South African. Currently...      Islamic State
# ...                                                  ...                ...
# 17380  If you have trust in Allah, you have no need t...                NaN
# 17381  17yr. old Freedom Activist\n/Correspondence of...            Germany
# 17382                                                NaN                NaN
# 17383  17yr. old Freedom Activist\n/Correspondence of...            Germany
# 17384                                                NaN                NaN
# 17385                                                NaN                NaN
# 17386  17yr. old Freedom Activist\n/Correspondence of...            Germany
# 17387  Here to defend the  American freedom and also ...         Texas, USA
# 17388                                                NaN                NaN
# 17389  Here to defend the  American freedom and also ...         Texas, USA
# 17390                                                NaN                NaN
# 17391  Here to defend the  American freedom and also ...         Texas, USA
# 17392  Here to defend the  American freedom and also ...         Texas, USA
# 17393  Torah Observant, follower of the Prophet Yeshu...        dar al-kufr
# 17394      War Investigator. Civil Engineer. MENA Region  Gaziantep, Turkey
# 17395  Here to defend the  American freedom and also ...         Texas, USA
# 17396  Here to defend the  American freedom and also ...         Texas, USA
# 17397  Here to defend the  American freedom and also ...         Texas, USA
# 17398  Here to defend the  American freedom and also ...         Texas, USA
# 17399  Here to defend the  American freedom and also ...         Texas, USA
# 17400                                                NaN                NaN
# 17401                                                NaN                NaN
# 17402  Here to defend the  American freedom and also ...         Texas, USA
# 17403                                                NaN                NaN
# 17404  Here to defend the  American freedom and also ...         Texas, USA
# 17405                                                NaN                NaN
# 17406                                                NaN                NaN
# 17407                                                NaN                NaN
# 17408                                                NaN                NaN
# 17409  Torah Observant, follower of the Prophet Yeshu...        dar al-kufr
#
#        followers  numberstatuses             time  \
# 0            640              49   1/6/2015 21:07
# 1            640              49   1/6/2015 21:27
# 2            640              49   1/6/2015 21:29
# 3            640              49   1/6/2015 21:37
# 4            640              49   1/6/2015 21:45
# 5            640              49   1/6/2015 21:51
# 6            640              49   1/6/2015 22:04
# 7            640              49   1/6/2015 22:06
# 8            640              49   1/6/2015 22:17
# 9            640              49   1/10/2015 0:05
# 10           640              49   1/10/2015 0:08
# 11           640              49  1/12/2015 23:10
# 12           640              49  1/22/2015 20:14
# 13           640              49  1/22/2015 20:47
# 14           640              49   2/9/2015 10:54
# 15           640              49  2/12/2015 13:03
# 16           640              49  2/12/2015 13:11
# 17           640              49  2/16/2015 15:57
# 18           640              49  2/20/2015 16:28
# 19           640              49  2/20/2015 16:29
# 20           640              49  2/20/2015 16:30
# 21           640              49  2/26/2015 20:36
# 22           640              49  2/26/2015 20:40
# 23           640              49  2/28/2015 23:35
# 24           640              49    3/4/2015 7:31
# 25           640              49   4/1/2015 13:18
# 26           640              49  5/13/2015 21:16
# 27           640              49   5/29/2015 9:53
# 28           640              49   6/3/2015 11:16
# 29            68              18    7/7/2015 6:02
# ...          ...             ...              ...
# 17380         81             478  5/13/2016 14:50
# 17381       4662            5966  5/13/2016 14:54
# 17382        238             133  5/13/2016 15:10
# 17383       4662            5966  5/13/2016 15:11
# 17384        427             142  5/13/2016 15:12
# 17385        238             133  5/13/2016 15:13
# 17386       4662            5966  5/13/2016 15:15
# 17387       1798            7028  5/13/2016 15:17
# 17388        238             133  5/13/2016 15:17
# 17389       1798            7028  5/13/2016 15:19
# 17390        238             133  5/13/2016 15:21
# 17391       1798            7028  5/13/2016 15:21
# 17392       1798            7028  5/13/2016 15:23
# 17393       1482           33091  5/13/2016 15:26
# 17394        528             259  5/13/2016 15:27
# 17395       1798            7028  5/13/2016 15:27
# 17396       1798            7028  5/13/2016 15:30
# 17397       1798            7028  5/13/2016 15:32
# 17398       1798            7028  5/13/2016 15:35
# 17399       1798            7028  5/13/2016 15:37
# 17400        427             142  5/13/2016 15:40
# 17401        427             142  5/13/2016 15:42
# 17402       1798            7028  5/13/2016 15:43
# 17403        238             133  5/13/2016 15:44
# 17404       1798            7028  5/13/2016 15:45
# 17405        238             133  5/13/2016 15:46
# 17406        238             133  5/13/2016 15:50
# 17407        238             133  5/13/2016 15:51
# 17408        238             133  5/13/2016 16:07
# 17409       1482           33091  5/13/2016 16:10
#
#                                                   tweets
# 0      ENGLISH TRANSLATION: 'A MESSAGE TO THE TRUTHFU...
# 1      ENGLISH TRANSLATION: SHEIKH FATIH AL JAWLANI '...
# 2      ENGLISH TRANSLATION: FIRST AUDIO MEETING WITH ...
# 3      ENGLISH TRANSLATION: SHEIKH NASIR AL WUHAYSHI ...
# 4      ENGLISH TRANSLATION: AQAP: 'RESPONSE TO SHEIKH...
# 5      THE SECOND CLIP IN A DA'WAH SERIES BY A SOLDIE...
# 6      ENGLISH TRANSCRIPT : OH MURABIT! : http://t.co...
# 7      ENGLISH TRANSLATION: 'A COLLECTION OF THE WORD...
# 8      Aslm Please share our new account after the pr...
# 9      ENGLISH TRANSLATION: AQAP STATEMENT REGARDING ...
# 10     @KhalidMaghrebi @seifulmaslul123 @CheerLeadUni...
# 11     NEW LINK, AFTER PREVIOUS ONE TAKEN DOWN:AQAP-'...
# 12     ENGLISH TRANSLATION- SHEIKH ABU HASAN AL KUWAI...
# 13     SHEIKH ABU HASSAN AL KUWAITI (HA): ADVICE OF N...
# 14     @IbnNabih1 @MuwMedia @Dawlat_islam7 Not transl...
# 15     Aslm, anybody translating the new JN video? Wi...
# 16     @IbnNabih1 @KhalidMaghrebi_ @MuwMedia @Polder_...
# 17     @IbnNabih1 @abuw_ukasyah @polder_mujaahid @Abu...
# 18     @AbdirahmanBash2 @KhalidMaghrebi_ @IbnNabih1 @...
# 19     @AbdirahmanBash2 @KhalidMaghrebi_ @IbnNabih1 @...
# 20     @AbdirahmanBash2 @KhalidMaghrebi_ @IbnNabih1 @...
# 21     NEW links for #JN Video - ENG Subs: The Path o...
# 22     DOWNLOAD #JN Video With English Subtitles: The...
# 23     Video by @ansardeenfront with Eng Subtitles: '...
# 24     ENGLISH TRANSLATION: A Pamphlet Released By #J...
# 25     Aslm, anybody translating the new audio of She...
# 26     @abuhamzaneh @50W30 @JN_Irhabiyya_97 @Aba_M0ha...
# 27     RT @GIIMedia_CH004: Rules Of Imarah Part2 - Co...
# 28     ENGLISH TRANSLATION: Dialogue with Sheikh Tart...
# 29     ‍‌‌‌‌‍‌‌‌🔻‌‌[ الإثنين  1436/9/19 هـ ]‍‌‌‌‌‍‍‍...
# ...                                                  ...
# 17380  RT @_The_Hikmah_: #IbnAlQayyim #Allah Ta`Aala\...
# 17381  Local Source: Daily and Heavy Clashes between ...
# 17382  #Breaking\n#IslamicState \n\n#Fallujah \n#Euro...
# 17383  HUGE\n\nAt least 300 Irani IRCG Soldiers were ...
# 17384  RT @anti_shirkkkk: "A single expedition in the...
# 17385  #Breaking\n#IslamicState Forces assault Iraqi ...
# 17386  RT @PalmyraPioneer: These images of the massac...
# 17387  @MehdiTh2 @_Darmouss @PeigneACheveux j'aimerai...
# 17388  3 Martyrdom bombers detonate their Xplosive be...
# 17389  @_Darmouss une légende de twitter, il a rejoin...
# 17390  #Breaking \n#IslamicState \n  || 3 Martydom bo...
# 17391  @HadjSarrasins pas mal ce tweet toi aussi tu v...
# 17392  RT @HadjSarrasins: Mais qui a envie d'entendre...
# 17393  #AmaqAgency so far 9 Iraqi hummers, an autocan...
# 17394  RT @RamiAlLolah: #Exclusive Photo: #Hezbollah ...
# 17395  According to the SOHR, JAN is responsible of t...
# 17396  Notice that the fighter who trample the bodies...
# 17397  The local commander of Ahrar Al Sham appears i...
# 17398  RT @SimNasr: #Syria: Who was Mustapha #Badredd...
# 17399  RT @SimNasr: Erratum shiaa Afghan fighters who...
# 17400  RT @jdanteff: Aamaq footage:\nDestruction of I...
# 17401  Heavy battles going on in Al Karmah northeast ...
# 17402  "Is the Islamic State trying  to draw Turkey i...
# 17403  9 Hummers an autocannon and a field artillery ...
# 17404  #LT Notice that this possible strategy was men...
# 17405  #Breaking\n#IslamicState \n#AmaqAgency \n\n#Fr...
# 17406  #Breaking\n\n Iraqi forces bulldozer destroyed...
# 17407  #Breaking \n#AmaqAgency \n#IslamicState \n\n#E...
# 17408  #PhotoReport \n#WilayatDimasiqh \n\n📷The Cond...
# 17409  #AmaqAgency Destroyed and burning Iraqi Forces...
#
# [17410 rows x 8 columns]

# %%
df.iloc[8]['tweets']
# Out:
# 'Aslm Please share our new account after the previous one was suspended.@KhalidMaghrebi @seifulmaslul123 @CheerLeadUnited'

# %% [markdown]
# ### Return all tagged profiles per tweet
#
# #### Tokenize Tweet text
#
# Consider @taggedprofile and #word as one token.

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(text):
    return tokens_re.findall(text)
 
def preprocess(text, lowercase=False):
    tokens = tokenize(text)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
# create new column for tokenized tweets that returns @taggedprofile as one token 
df['tokenized_tweets'] = df['tweets'].apply(lambda x: preprocess(x))

# %%
# create new column that returns only the tokens that refer to a tagged profile
df['tagged_profiles'] = df['tokenized_tweets'].map(lambda x: [token for token in x if token.startswith('@')])

# %% [markdown]
# ### Add topic to tweet

# %%
# remove urls from tweets
import re
df['tweets'] = df['tweets'].apply(lambda x: re.sub(r'http\S+', '', x))

# %%
# add index name to dataframe
df = df.reset_index()

# %%
# create a list of tuples of tweets and index of tweet
tweets = df['tweets'].tolist()
index = df['index'].values.tolist()
tweets_index = zip(index, tweets)
tweets_index[:5]
# Out:
# [(0,
#   "ENGLISH TRANSLATION: 'A MESSAGE TO THE TRUTHFUL IN SYRIA - SHEIKH ABU MUHAMMED AL MAQDISI:  "),
#  (1,
#   "ENGLISH TRANSLATION: SHEIKH FATIH AL JAWLANI 'FOR THE PEOPLE OF INTEGRITY, SACRIFICE IS  EASY'  "),
#  (2,
#   'ENGLISH TRANSLATION: FIRST AUDIO MEETING WITH SHEIKH FATIH AL JAWLANI (HA):  '),
#  (3,
#   "ENGLISH TRANSLATION: SHEIKH NASIR AL WUHAYSHI (HA), LEADER OF AQAP: 'THE PROMISE OF VICTORY':  "),
#  (4,
#   "ENGLISH TRANSLATION: AQAP: 'RESPONSE TO SHEIKH BAGHDADIS STATEMENT 'ALTHOUGH THE DISBELIEVERS DISLIKE IT.' ")]

# %%
# import modules
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np

# %%
def get_topic_relevancy_per_message(list_of_document_index_and_message, no_features=1000, no_topics=4): # include parameters in function (no_features, no_topics)

    document_index = [row[0] for row in list_of_document_index_and_message]
    documents = [row[1] for row in list_of_document_index_and_message]

    # get term counts 
    tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
    tf = tf_vectorizer.fit_transform(documents)
    tf_feature_names = tf_vectorizer.get_feature_names()

    # convert to arrays
    tf_array = tf_vectorizer.fit_transform(documents).toarray()
    tf_feature_names_array = np.array(tf_vectorizer.get_feature_names())

    # run model
    lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
    doctopic = lda.fit_transform(tf_array)

    # scale the document-component matrix such that the component values associated with each document sum to one
    doctopic = doctopic / np.sum(doctopic, axis=1, keepdims=True)

    # give each document a name (name of the index) 
    # and convert the name of each document to an array
    documents_names = np.asarray(document_index)
    doctopic_orig = doctopic.copy()

    # create a matrix that returns the relevance of a topic per document
    num_groups = len(set(documents_names))
    doctopic_grouped = np.zeros((num_groups, no_topics))
    for i, name in enumerate(sorted(set(documents_names))):
        doctopic_grouped[i, :] = np.mean(doctopic[documents_names == name, :], axis=0)

    # get the importantance of each topic per document
    doctopic = doctopic_grouped


    # print documents
    # print display_topics(nmf, tfidf_feature_names, no_top_words) 
    # print doctopic

    return doctopic

# %%
def return_document_and_most_important_topic_and_value(list_of_document_index_and_message, no_features=1000, no_topics=4):
    
    doctopic = get_topic_relevancy_per_message(list_of_document_index_and_message, no_features=no_features, no_topics=no_topics) 

    document_index = [row[0] for row in list_of_document_index_and_message]
    documents = [row[0] for row in list_of_document_index_and_message]
    
    # give each document a name (name of the index) 
    # and convert the name of each document to an array

    doctopic_list = doctopic.tolist()
    documents_names = np.asarray(document_index)
    documents_names_list = documents_names.tolist()

    documents_names_doctopics = zip(documents_names_list, doctopic_list)
    
    # create dataframe of array with topic names as column names
    column_names = range(len(doctopic[0]))
    topic_names = ["topic" + str(i) for i in column_names]

    df = pd.DataFrame(doctopic, index=documents_names, columns=topic_names)

    # return max value for each row
    # convert column to list
    max_value = df.max(axis=1).tolist()

    # create new column that states the topic that is most important for the document 
    # convert column to list
    topic = df.idxmax(axis=1).tolist()

    # create list of most important topic and highest value per document
    document_topic_value = zip(documents_names, topic, max_value)

    return document_topic_value

# %%
def return_messages_with_clear_topic(list_of_document_index_and_message, no_features=1000, no_topics=4, threshold=0):
    """return documents where topic relevancy is > a certain level"""
    document_topic_value = return_document_and_most_important_topic_and_value(list_of_document_index_and_message, no_features=no_features, no_topics=no_topics)
    
    df = pd.DataFrame(document_topic_value, columns = ['documents_names', 'topic', 'max_value'])

    # keep only the rows where value > threshold
    df_relevant = df[df['max_value'] > threshold]

    # convert this dataframe to a list
    relevant_doctopics = df_relevant.values.tolist()

    return relevant_doctopics

# %%
def return_topwords_topdocuments_per_topic(list_of_document_index_and_message, no_topics=0, no_top_words=0, no_top_documents=0): 
    
    documents = [row[1] for row in list_of_document_index_and_message]
    
    # import modules
    from sklearn.feature_extraction.text import CountVectorizer
    from sklearn.decomposition import LatentDirichletAllocation
    import numpy as np

    # prepare data for model
    tf_vectorizer = CountVectorizer(max_df=0.95, min_df=0.01, stop_words='english')
    tf = tf_vectorizer.fit_transform(documents)
    tf_feature_names = tf_vectorizer.get_feature_names()

    lda_model = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
    lda_W = lda_model.transform(tf)
    lda_H = lda_model.components_

    def display_topwords_topdocuments_per_topic(H, W, feature_names, documents, no_top_words, no_top_documents):
        for topic_idx, topic in enumerate(H):
            print "Topic %d:" % (topic_idx)
            print " ".join([feature_names[i]
                            for i in topic.argsort()[:-no_top_words - 1:-1]])
            top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
            for doc_index in top_doc_indices:
                print documents[doc_index]
    
    return display_topwords_topdocuments_per_topic(lda_H, lda_W, tf_feature_names, documents, no_top_words, no_top_documents)

# %%
# %%time
tweet_topic = return_document_and_most_important_topic_and_value(tweets_index, no_topics=5)
# Out:
# CPU times: user 41.8 s, sys: 301 ms, total: 42.1 s
# Wall time: 42.3 s

# %%
tweet_topic[:5]
# Out:
# [(0, 'topic4', 0.37178027166032135),
#  (1, 'topic1', 0.5106151896958239),
#  (2, 'topic1', 0.8337247690729706),
#  (3, 'topic1', 0.4920825812772331),
#  (4, 'topic1', 0.8626235165628258)]

# %%
# %%time
return_messages_with_clear_topic(tweets_index, threshold=0.8)[:5]
# Out:
# CPU times: user 47.5 s, sys: 459 ms, total: 47.9 s
# Wall time: 48.8 s
# [[0, 'topic3', 0.9053934038959924],
#  [1, 'topic3', 0.8744746384392372],
#  [2, 'topic3', 0.8491833584587678],
#  [3, 'topic3', 0.9059774387788857],
#  [4, 'topic3', 0.8742651239245751]]

# %%
# %%time
return_topwords_topdocuments_per_topic(tweets_index, no_topics=4, no_top_words=20, no_top_documents=1)
# Out:
# Topic 0:
# rt isis syria amp iraq ramiallolah city people assad army video new west fallujah attack russia libya mosul muslim war
# RT @RamiAlLolah: #ISIS issues a warning and precaution procedures to civilians after reports swine flu is spreading in #Syria &amp; #Iraq
# Topic 1:
# al allah today islamicstate abu regime damascus just warreporter1 islam claims don support news la south attack nusra baghdad killed
# @3diyah1000: Most popular attacks in Somalia last years : #dayniile attack, #Lego attack, #Jannale attack, #Yurkud attack.
# #Somalia
# Topic 2:
# state islamic breaking amaqagency fighters ypg area turkey like military fsa الله fight east في group know control says new
# الله أكبر الله أكبر الله أكبر ولله الحمد
# الله أكبر الله أكبر الله أكبر ولله الحمد
# الله أكبر الله أكبر الله أكبر ولله الحمد
# Topic 3:
# rt killed forces near army aleppo iraqi soldiers syrian rebels usa destroyed assad palmyra ramadi north muslims airstrikes saudi russian
# RT @Nidalgazaui: #Shiite militants killed a number of #Saudi soldiers near Saudi #Iraqi border in an assault on #Saudi army positions
# CPU times: user 17.3 s, sys: 106 ms, total: 17.4 s
# Wall time: 17.5 s

# %%
# add topic to df with tweets
row_topic = [(row[0], row[1]) for row in tweet_topic]

# convert list of tuples to dataframe
df_tweet_topic = pd.DataFrame(row_topic, columns=['index', 'topic'])

# %%
# merge df_tweet_topic with df
df = df.merge(df_tweet_topic, on='index', how='left')
df.head()
# Out:
#    index           name         username  \
# 0      0  GunsandCoffee  GunsandCoffee70
# 1      1  GunsandCoffee  GunsandCoffee70
# 2      2  GunsandCoffee  GunsandCoffee70
# 3      3  GunsandCoffee  GunsandCoffee70
# 4      4  GunsandCoffee  GunsandCoffee70
#
#                                     description location  followers  \
# 0  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 1  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 2  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 3  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 4  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
#
#    numberstatuses            time  \
# 0              49  1/6/2015 21:07
# 1              49  1/6/2015 21:27
# 2              49  1/6/2015 21:29
# 3              49  1/6/2015 21:37
# 4              49  1/6/2015 21:45
#
#                                               tweets  \
# 0  ENGLISH TRANSLATION: 'A MESSAGE TO THE TRUTHFU...
# 1  ENGLISH TRANSLATION: SHEIKH FATIH AL JAWLANI '...
# 2  ENGLISH TRANSLATION: FIRST AUDIO MEETING WITH ...
# 3  ENGLISH TRANSLATION: SHEIKH NASIR AL WUHAYSHI ...
# 4  ENGLISH TRANSLATION: AQAP: 'RESPONSE TO SHEIKH...
#
#                                     tokenized_tweets tagged_profiles   topic
# 0  [ENGLISH, TRANSLATION, :, ', A, MESSAGE, TO, T...              []  topic4
# 1  [ENGLISH, TRANSLATION, :, SHEIKH, FATIH, AL, J...              []  topic1
# 2  [ENGLISH, TRANSLATION, :, FIRST, AUDIO, MEETIN...              []  topic1
# 3  [ENGLISH, TRANSLATION, :, SHEIKH, NASIR, AL, W...              []  topic1
# 4  [ENGLISH, TRANSLATION, :, AQAP, :, ', RESPONSE...              []  topic1

# %% [markdown]
# ### Make a selection of the columns (user, tagged profiles, tweets, tweet topic) and reduce the dataset to only active users and connections

# %%
# create new dataframe that contains username, tagged_profiles and topic
df_profiles_topic = df[['index', 'username', 'tagged_profiles', 'topic']]

# keep only the tweets that contain a tagged profile
df_profiles_topic = df_profiles_topic[df_profiles_topic.astype(str)['tagged_profiles'] != '[]']
df_profiles_topic.head()
# Out:
#     index         username                                    tagged_profiles  \
# 8       8  GunsandCoffee70  [@KhalidMaghrebi, @seifulmaslul123, @CheerLead...
# 10     10  GunsandCoffee70  [@KhalidMaghrebi, @seifulmaslul123, @CheerLead...
# 14     14  GunsandCoffee70            [@IbnNabih1, @MuwMedia, @Dawlat_islam7]
# 15     15  GunsandCoffee70  [@IbnNabih1, @KhalidMaghrebi_, @MuwMedia, @Pol...
# 16     16  GunsandCoffee70  [@IbnNabih1, @KhalidMaghrebi_, @MuwMedia, @Pol...
#
#      topic
# 8   topic3
# 10  topic0
# 14  topic0
# 15  topic3
# 16  topic0

# %%
# remove @ character from tagged profiles
df_profiles_topic['tagged_profiles'] = df_profiles_topic['tagged_profiles'].apply(lambda x: [token.replace('@','') for token in x])
df_profiles_topic.head()
# Out:
#     index         username                                    tagged_profiles  \
# 8       8  GunsandCoffee70  [KhalidMaghrebi, seifulmaslul123, CheerLeadUni...
# 10     10  GunsandCoffee70  [KhalidMaghrebi, seifulmaslul123, CheerLeadUni...
# 14     14  GunsandCoffee70               [IbnNabih1, MuwMedia, Dawlat_islam7]
# 15     15  GunsandCoffee70  [IbnNabih1, KhalidMaghrebi_, MuwMedia, Polder_...
# 16     16  GunsandCoffee70  [IbnNabih1, KhalidMaghrebi_, MuwMedia, Polder_...
#
#      topic
# 8   topic3
# 10  topic0
# 14  topic0
# 15  topic3
# 16  topic0

# %%
set(df_profiles_topic.iloc[0]['tagged_profiles'])
# Out:
# {'CheerLeadUnited', 'KhalidMaghrebi', 'seifulmaslul123'}

# %%
# retrieve list of unique tagged profiles
tagged_profiles = list(set([pair for row in df_profiles_topic['tagged_profiles'] for pair in row]))
print len(tagged_profiles)
tagged_profiles[:5]
# Out:
# 3301
# ['', 'Jazrawi_3uud', '5629haqq', 'VSOForever', 'AsebAlRasWenak']

# %%
# retrieve list of unique usernames
usernames = list(df_profiles_topic['username'].unique())
print len(usernames)
usernames[:5]
# Out:
# 107
# ['GunsandCoffee70',
#  'YazeedDhardaa25',
#  'BaqiyaIs',
#  'abubakerdimshqi',
#  'WhiteCat_7']

# %%
# get number of unique tagged profiles and unique usernames
print '# unique tagged profiles: ', len(tagged_profiles)
print '# unique usernames: ', len(usernames)
# Out:
# # unique tagged profiles:  3301
# # unique usernames:  107

# %%
# check on passive accounts
print 'Jazrawi_3uud' in tagged_profiles
print 'Jazrawi_3uud' in usernames
# Out:
# True
# False

# %% [markdown]
# Some Twitter users are tagged, but don't post tweets themselves.
# This could imply that those users that are tagged, but don't post tweets themselves, refer to passive accounts.
#
# We may be interested in the profiles of those passive accounts.

# %%
len([account for account in tagged_profiles if account in usernames])
# Out:
# 77

# %% [markdown]
# 77 profiles out of 3301 profiles are members that both post a tweet as well as get tagged by other members.

# %%
len([account for account in tagged_profiles if account not in usernames])
# Out:
# 3224

# %% [markdown]
# This implies indeed that 3224 profiles are passive accounts.
#
# Store both the profiles of active accounts and passive accounts in a separate list.
# For the network analysis we willn not use the passive profiles.

# %%
active_accounts = [account for account in tagged_profiles if account in usernames]
passive_accounts = [account for account in tagged_profiles if account not in usernames]
print '# of active accounts:', len(active_accounts)
print '# of passive accounts:', len(passive_accounts)
# Out:
# # of active accounts: 77
# # of passive accounts: 3224

# %%
# create a dataframe that only contains the active accounts
df_profiles_topic['tagged_profiles'] = df_profiles_topic['tagged_profiles'].apply(lambda x: [account for account in x if account in usernames])
print len(df_profiles_topic)

# keep only the tweets that contain a tagged profile
df_profiles_topic = df_profiles_topic[df_profiles_topic.astype(str)['tagged_profiles'] != '[]']
print len(df_profiles_topic)

df_profiles_topic.head()
# Out:
# 9878
# 1953
#      index         username    tagged_profiles   topic
# 32      32  YazeedDhardaa25  [YazeedDhardaa25]  topic0
# 174    174  YazeedDhardaa25      [RamiAlLolah]  topic3
# 180    180  YazeedDhardaa25      [RamiAlLolah]  topic4
# 181    181  YazeedDhardaa25      [RamiAlLolah]  topic4
# 186    186  YazeedDhardaa25  [YazeedDhardaa25]  topic1

# %% [markdown]
# ### Prepare data for network analysis
#
# #### - Create a list of connections as a pair of tuples
#
# Output should look like this:
#
#     [(username, tagged_profile1), (username, tagged_profile2), (username, tagged_profile3)]
#
#
#
#
# #### - Add attributes to connections
#
# A connection can have multiple topics
#
# Output should look like this:
#
#     {(username, tagged_profile1): topic1,
#      (username, tagged_profile2): topic1,
#      (username, tagged_profile3): topic1,
#      (username, tagged_profile1): topic2,
#      (username, tagged_profile2): topic2,
#      (username, tagged_profile1): topic3,}

# %%
# create a dataframe that only stores the username and tagged profiles
df_connections = df_profiles_topic[['username', 'tagged_profiles']]
print len(df_connections)
df_connections.head()
# Out:
# 1953
#             username    tagged_profiles
# 32   YazeedDhardaa25  [YazeedDhardaa25]
# 174  YazeedDhardaa25      [RamiAlLolah]
# 180  YazeedDhardaa25      [RamiAlLolah]
# 181  YazeedDhardaa25      [RamiAlLolah]
# 186  YazeedDhardaa25  [YazeedDhardaa25]

# %%
# create another dataframe that only stores the username and topic
df_username_topic = df_profiles_topic[['username', 'topic']]
print len(df_username_topic)
df_username_topic.head()
# Out:
# 1953
#             username   topic
# 32   YazeedDhardaa25  topic0
# 174  YazeedDhardaa25  topic3
# 180  YazeedDhardaa25  topic4
# 181  YazeedDhardaa25  topic4
# 186  YazeedDhardaa25  topic1

# %%
# # get number of tags per tagged profile

# usernames_tuple = list(set([username[0] for username in edges]))
# print usernames_tuple[:5]
# print '---'
# tagged_profiles_tuple = [tagged_profile[1] for tagged_profile in edges]
# print tagged_profiles_tuple[:5]
# print '---'
# print 'Bedouin127' in tagged_profiles_tuple
# print '---'
# from collections import Counter
# number_of_tags_per_tagged_profile_dict = Counter(tagged_profiles_tuple)

# print number_of_tags_per_tagged_profile_dict.get('Bedouin127')
# print '---'
# print number_of_tags_per_tagged_profile_dict

# %%
# convert both dataframes to dictionary

# df connection
connections_dict = df_connections.set_index('username').T.to_dict(orient='list')
print len(connections_dict.keys())
print connections_dict
print '---'
# df username topic
username_topic_dict = df_username_topic.set_index('username').T.to_dict(orient='list')
print len(username_topic_dict.keys())
print username_topic_dict
# Out:
# 87
# {'murasil1': [['WarReporter1']], 'Suspend_Me_fags': [['Suspend_Me_fags']], 'Uncle_SamCoco': [['WarReporter1']], 'maisaraghereeb': [['maisaraghereeb']], '432Mryam': [['abuayisha102']], 'Witness_alHaqq': [['WarReporter1']], 'ismailmahsud': [['ismailmahsud']], 'ks48a174031': [['RamiAlLolah']], 'Afriqqiya_252': [['Afriqqiya_252', 'Afriqqiya_252', 'Afriqqiya_252', 'Afriqqiya_252']], 'wayf44rerr': [['AbuMusab_110']], 'freelance_112': [['freelance_112']], 'Nidalgazaui': [['warrnews']], 'ro34th': [['Uncle_SamCoco']], 'MilkSheikh2': [['AsimAbuMerjem']], '_IshfaqAhmad': [['Nidalgazaui']], '__alfresco__': [['WarReporter1']], 'Fidaee_Fulaani': [['Fidaee_Fulaani']], 'WhiteCat_7': [['mobi_ayubi']], 'abuhanzalah10': [['RamiAlLolah']], 'melvynlion': [['melvynlion']], 'Jazrawi_Joulan': [['MaghrebiHD']], 'Mountainjjoool': [['nvor85j']], 'al_nusra': [['al_nusra']], 'st3erer': [['AbuMusab_110']], 'MaghrebiWM': [['RamiAlLolah']], 'fahadslay614': [['fahadslay614', 'fahadslay614', 'fahadslay614', 'fahadslay614']], 'darulhijrateyni': [['MaghrebiQM']], 'Bajwa47online': [['Bajwa47online']], 'klakishinki': [['RamiAlLolah']], 'Jazrawi_Saraqib': [['MaghrebiWM']], 'Freedom_speech2': [['Jazrawi_Joulan']], 'abuhumayra4': [['MilkSheikh2']], 'wayyf44rer': [['RamiAlLolah']], '04_8_1437': [['04_8_1437', '04_8_1437', '04_8_1437']], 'moustiklash': [['_IshfaqAhmad']], 'AbdusMujahid149': [['AbdusMujahid149']], 'FidaeeFulaani': [['RamiAlLolah']], 'Al_Battar_Engl': [['Al_Battar_Engl']], 'YazeedDhardaa25': [['RamiAlLolah']], 'QassamiMarwan': [['MaghrebiQM']], 'JoinISNation102': [['Nidalgazaui']], 'Abu_Ibn_Taha': [['Baqiyah_Khilafa']], 'AbuMusab_110': [['kIakishini5']], 'Baqiyah_Khilafa': [['Jazrawi_Joulan']], '1515Ummah': [['mustaklash']], 'Alwala_bara': [['RamiAlLolah']], 'warreporter2': [['RamiAlLolah']], 'DabiqsweetsMan': [['RamiAlLolah']], 'sonofshishan': [['__alfresco__']], 'MaghrebiQM': [['RamiAlLolah']], '06230550_IS': [['MaghrebiHD']], 'saifulakhir': [['Nidalgazaui']], 'Battar_English': [['Battar_English']], 'abutariq040': [['DawlaWitness11']], 'abutariq041': [['emran_getu']], 'ManKhalfahum': [['mustaklash']], 'JohnsonsBot': [['RamiAlLolah']], 'IbnKashmir_': [['Jazrawi_Saraqib']], 'Abu_Azzzam25': [['RamiAlLolah']], 'mustaklash': [['RamiAlLolah']], 'thefIamesofhaqq': [['MaghrebiHD']], 'war_analysis': [['saifulakhir']], 'mobi_ayubi': [['warrnews']], 'abdlrhmn15': [['RamiAlLolah']], 'safiyaimback': [['Nidalgazaui', 'warrnews']], 'DawlaWitness11': [['MaghrebiWM']], 'alamreeki4': [['RamiAlLolah']], 'grezz10': [['RamiAlLolah']], 'baaqiya_01': [['mustafaklash56']], 'abuayisha108': [['WarReporter1']], 'EPlC24': [['MaghrebiHD']], 'btt_ar': [['btt_ar']], 'abuayisha102': [['432Mryam']], 'MaghrabiArabi': [['lNSlDEWAR']], 'NaseemAhmed50': [['DawlaWitness11']], 'RamiAlLolah': [['Nidalgazaui']], 'BilalIbnRabah1': [['Nidalgazaui']], 'lNSlDEWAR': [['RamiAlLolah']], 'ansarakhilafa': [['mustafaklash56']], 'dieinurage29__7': [['baaqiya_01']], 'WarReporter1': [['Uncle_SamCoco']], 'kIakishini5': [['freelance_112', 'freelance_112']], 'AsimAbuMerjem': [['Nidalgazaui']], 'AbuNaseeha_03': [['MaghrebiQM']], 'warrnews': [['Nidalgazaui', 'RamiAlLolah']], 'mustafaklash56': [['mustafaklash56']], 'Dieinurage308': [['Dieinurage308', 'Dieinurage308', 'Dieinurage308', 'Dieinurage308']]}
# ---
# 87
# {'murasil1': ['topic3'], 'Suspend_Me_fags': ['topic3'], 'Uncle_SamCoco': ['topic0'], 'maisaraghereeb': ['topic3'], '432Mryam': ['topic0'], 'Witness_alHaqq': ['topic3'], 'ismailmahsud': ['topic1'], 'ks48a174031': ['topic3'], 'Afriqqiya_252': ['topic1'], 'wayf44rerr': ['topic3'], 'freelance_112': ['topic2'], 'Nidalgazaui': ['topic3'], 'ro34th': ['topic0'], 'MilkSheikh2': ['topic0'], '_IshfaqAhmad': ['topic3'], '__alfresco__': ['topic4'], 'Fidaee_Fulaani': ['topic0'], 'WhiteCat_7': ['topic2'], 'abuhanzalah10': ['topic3'], 'melvynlion': ['topic0'], 'Jazrawi_Joulan': ['topic2'], 'Mountainjjoool': ['topic2'], 'al_nusra': ['topic2'], 'st3erer': ['topic3'], 'MaghrebiWM': ['topic4'], 'fahadslay614': ['topic2'], 'darulhijrateyni': ['topic4'], 'Bajwa47online': ['topic2'], 'klakishinki': ['topic3'], 'Jazrawi_Saraqib': ['topic0'], 'Freedom_speech2': ['topic1'], 'abuhumayra4': ['topic0'], 'wayyf44rer': ['topic4'], '04_8_1437': ['topic3'], 'moustiklash': ['topic1'], 'AbdusMujahid149': ['topic0'], 'FidaeeFulaani': ['topic2'], 'Al_Battar_Engl': ['topic1'], 'YazeedDhardaa25': ['topic4'], 'QassamiMarwan': ['topic4'], 'JoinISNation102': ['topic2'], 'Abu_Ibn_Taha': ['topic1'], 'AbuMusab_110': ['topic0'], 'Baqiyah_Khilafa': ['topic1'], '1515Ummah': ['topic2'], 'Alwala_bara': ['topic4'], 'warreporter2': ['topic3'], 'DabiqsweetsMan': ['topic3'], 'sonofshishan': ['topic0'], 'MaghrebiQM': ['topic4'], '06230550_IS': ['topic0'], 'saifulakhir': ['topic4'], 'Battar_English': ['topic1'], 'abutariq040': ['topic0'], 'abutariq041': ['topic1'], 'ManKhalfahum': ['topic2'], 'JohnsonsBot': ['topic4'], 'IbnKashmir_': ['topic1'], 'Abu_Azzzam25': ['topic4'], 'mustaklash': ['topic3'], 'thefIamesofhaqq': ['topic2'], 'war_analysis': ['topic2'], 'mobi_ayubi': ['topic4'], 'abdlrhmn15': ['topic3'], 'safiyaimback': ['topic2'], 'DawlaWitness11': ['topic3'], 'alamreeki4': ['topic2'], 'grezz10': ['topic4'], 'baaqiya_01': ['topic1'], 'abuayisha108': ['topic0'], 'EPlC24': ['topic0'], 'btt_ar': ['topic1'], 'abuayisha102': ['topic2'], 'MaghrabiArabi': ['topic3'], 'NaseemAhmed50': ['topic3'], 'RamiAlLolah': ['topic2'], 'BilalIbnRabah1': ['topic2'], 'lNSlDEWAR': ['topic3'], 'ansarakhilafa': ['topic2'], 'dieinurage29__7': ['topic1'], 'WarReporter1': ['topic3'], 'kIakishini5': ['topic2'], 'AsimAbuMerjem': ['topic4'], 'AbuNaseeha_03': ['topic3'], 'warrnews': ['topic4'], 'mustafaklash56': ['topic0'], 'Dieinurage308': ['topic0']}
# /Users/annalie/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:882: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "columns will be omitted.", UserWarning)

# %%
# # convert dataframe to dictionary
# user_topics_dict = df_.set_index('username').T.to_dict(orient='list')
# user_topics_dict

# %%
# create the edges (connections) of the graph

# convert the connections dictionary to a list of tuples where each key corresponds to its value in the dictionary

def get_connections(dictionary_with_list_of_values):
    connections = []
    for user,value in dictionary_with_list_of_values.iteritems():
        for item in value:
            for profile in item:
                connections.append((user, profile))
    return connections

edges = get_connections(connections_dict)
print len(edges)
print edges
# Out:
# 101
# [('murasil1', 'WarReporter1'), ('Suspend_Me_fags', 'Suspend_Me_fags'), ('Uncle_SamCoco', 'WarReporter1'), ('maisaraghereeb', 'maisaraghereeb'), ('432Mryam', 'abuayisha102'), ('Witness_alHaqq', 'WarReporter1'), ('ismailmahsud', 'ismailmahsud'), ('ks48a174031', 'RamiAlLolah'), ('Afriqqiya_252', 'Afriqqiya_252'), ('Afriqqiya_252', 'Afriqqiya_252'), ('Afriqqiya_252', 'Afriqqiya_252'), ('Afriqqiya_252', 'Afriqqiya_252'), ('wayf44rerr', 'AbuMusab_110'), ('freelance_112', 'freelance_112'), ('Nidalgazaui', 'warrnews'), ('ro34th', 'Uncle_SamCoco'), ('MilkSheikh2', 'AsimAbuMerjem'), ('_IshfaqAhmad', 'Nidalgazaui'), ('__alfresco__', 'WarReporter1'), ('Fidaee_Fulaani', 'Fidaee_Fulaani'), ('WhiteCat_7', 'mobi_ayubi'), ('abuhanzalah10', 'RamiAlLolah'), ('melvynlion', 'melvynlion'), ('Jazrawi_Joulan', 'MaghrebiHD'), ('Mountainjjoool', 'nvor85j'), ('al_nusra', 'al_nusra'), ('st3erer', 'AbuMusab_110'), ('MaghrebiWM', 'RamiAlLolah'), ('fahadslay614', 'fahadslay614'), ('fahadslay614', 'fahadslay614'), ('fahadslay614', 'fahadslay614'), ('fahadslay614', 'fahadslay614'), ('darulhijrateyni', 'MaghrebiQM'), ('Bajwa47online', 'Bajwa47online'), ('klakishinki', 'RamiAlLolah'), ('Jazrawi_Saraqib', 'MaghrebiWM'), ('Freedom_speech2', 'Jazrawi_Joulan'), ('abuhumayra4', 'MilkSheikh2'), ('wayyf44rer', 'RamiAlLolah'), ('04_8_1437', '04_8_1437'), ('04_8_1437', '04_8_1437'), ('04_8_1437', '04_8_1437'), ('moustiklash', '_IshfaqAhmad'), ('AbdusMujahid149', 'AbdusMujahid149'), ('FidaeeFulaani', 'RamiAlLolah'), ('Al_Battar_Engl', 'Al_Battar_Engl'), ('YazeedDhardaa25', 'RamiAlLolah'), ('QassamiMarwan', 'MaghrebiQM'), ('JoinISNation102', 'Nidalgazaui'), ('Abu_Ibn_Taha', 'Baqiyah_Khilafa'), ('AbuMusab_110', 'kIakishini5'), ('Baqiyah_Khilafa', 'Jazrawi_Joulan'), ('1515Ummah', 'mustaklash'), ('Alwala_bara', 'RamiAlLolah'), ('warreporter2', 'RamiAlLolah'), ('DabiqsweetsMan', 'RamiAlLolah'), ('sonofshishan', '__alfresco__'), ('MaghrebiQM', 'RamiAlLolah'), ('06230550_IS', 'MaghrebiHD'), ('saifulakhir', 'Nidalgazaui'), ('Battar_English', 'Battar_English'), ('abutariq040', 'DawlaWitness11'), ('abutariq041', 'emran_getu'), ('ManKhalfahum', 'mustaklash'), ('JohnsonsBot', 'RamiAlLolah'), ('IbnKashmir_', 'Jazrawi_Saraqib'), ('Abu_Azzzam25', 'RamiAlLolah'), ('mustaklash', 'RamiAlLolah'), ('thefIamesofhaqq', 'MaghrebiHD'), ('war_analysis', 'saifulakhir'), ('mobi_ayubi', 'warrnews'), ('abdlrhmn15', 'RamiAlLolah'), ('safiyaimback', 'Nidalgazaui'), ('safiyaimback', 'warrnews'), ('DawlaWitness11', 'MaghrebiWM'), ('alamreeki4', 'RamiAlLolah'), ('grezz10', 'RamiAlLolah'), ('baaqiya_01', 'mustafaklash56'), ('abuayisha108', 'WarReporter1'), ('EPlC24', 'MaghrebiHD'), ('btt_ar', 'btt_ar'), ('abuayisha102', '432Mryam'), ('MaghrabiArabi', 'lNSlDEWAR'), ('NaseemAhmed50', 'DawlaWitness11'), ('RamiAlLolah', 'Nidalgazaui'), ('BilalIbnRabah1', 'Nidalgazaui'), ('lNSlDEWAR', 'RamiAlLolah'), ('ansarakhilafa', 'mustafaklash56'), ('dieinurage29__7', 'baaqiya_01'), ('WarReporter1', 'Uncle_SamCoco'), ('kIakishini5', 'freelance_112'), ('kIakishini5', 'freelance_112'), ('AsimAbuMerjem', 'Nidalgazaui'), ('AbuNaseeha_03', 'MaghrebiQM'), ('warrnews', 'Nidalgazaui'), ('warrnews', 'RamiAlLolah'), ('mustafaklash56', 'mustafaklash56'), ('Dieinurage308', 'Dieinurage308'), ('Dieinurage308', 'Dieinurage308'), ('Dieinurage308', 'Dieinurage308'), ('Dieinurage308', 'Dieinurage308')]

# %%
# add topics to connections

def get_connections_topic(connections_dict, username_topic_dict):
    """Get a separate list of the topic per tweet and per connection
    between user and tagged profile."""
    
    connections_topic_dict = {}
    for user1,value1 in connections_dict.iteritems():
        for user2,value2 in username_topic_dict.iteritems():
            if user1 == user2:

                for item in value1:
                    for profile in item:

                        for topic in value2:
                            connections_topic_dict[(user1, profile)] = topic
    return connections_topic_dict

# %%
connection_topic = get_connections_topic(connections_dict, username_topic_dict)
print len(connection_topic)
connection_topic
# Out:
# 89
# {('04_8_1437', '04_8_1437'): 'topic3',
#  ('06230550_IS', 'MaghrebiHD'): 'topic0',
#  ('1515Ummah', 'mustaklash'): 'topic2',
#  ('432Mryam', 'abuayisha102'): 'topic0',
#  ('AbdusMujahid149', 'AbdusMujahid149'): 'topic0',
#  ('AbuMusab_110', 'kIakishini5'): 'topic0',
#  ('AbuNaseeha_03', 'MaghrebiQM'): 'topic3',
#  ('Abu_Azzzam25', 'RamiAlLolah'): 'topic4',
#  ('Abu_Ibn_Taha', 'Baqiyah_Khilafa'): 'topic1',
#  ('Afriqqiya_252', 'Afriqqiya_252'): 'topic1',
#  ('Al_Battar_Engl', 'Al_Battar_Engl'): 'topic1',
#  ('Alwala_bara', 'RamiAlLolah'): 'topic4',
#  ('AsimAbuMerjem', 'Nidalgazaui'): 'topic4',
#  ('Bajwa47online', 'Bajwa47online'): 'topic2',
#  ('Baqiyah_Khilafa', 'Jazrawi_Joulan'): 'topic1',
#  ('Battar_English', 'Battar_English'): 'topic1',
#  ('BilalIbnRabah1', 'Nidalgazaui'): 'topic2',
#  ('DabiqsweetsMan', 'RamiAlLolah'): 'topic3',
#  ('DawlaWitness11', 'MaghrebiWM'): 'topic3',
#  ('Dieinurage308', 'Dieinurage308'): 'topic0',
#  ('EPlC24', 'MaghrebiHD'): 'topic0',
#  ('FidaeeFulaani', 'RamiAlLolah'): 'topic2',
#  ('Fidaee_Fulaani', 'Fidaee_Fulaani'): 'topic0',
#  ('Freedom_speech2', 'Jazrawi_Joulan'): 'topic1',
#  ('IbnKashmir_', 'Jazrawi_Saraqib'): 'topic1',
#  ('Jazrawi_Joulan', 'MaghrebiHD'): 'topic2',
#  ('Jazrawi_Saraqib', 'MaghrebiWM'): 'topic0',
#  ('JohnsonsBot', 'RamiAlLolah'): 'topic4',
#  ('JoinISNation102', 'Nidalgazaui'): 'topic2',
#  ('MaghrabiArabi', 'lNSlDEWAR'): 'topic3',
#  ('MaghrebiQM', 'RamiAlLolah'): 'topic4',
#  ('MaghrebiWM', 'RamiAlLolah'): 'topic4',
#  ('ManKhalfahum', 'mustaklash'): 'topic2',
#  ('MilkSheikh2', 'AsimAbuMerjem'): 'topic0',
#  ('Mountainjjoool', 'nvor85j'): 'topic2',
#  ('NaseemAhmed50', 'DawlaWitness11'): 'topic3',
#  ('Nidalgazaui', 'warrnews'): 'topic3',
#  ('QassamiMarwan', 'MaghrebiQM'): 'topic4',
#  ('RamiAlLolah', 'Nidalgazaui'): 'topic2',
#  ('Suspend_Me_fags', 'Suspend_Me_fags'): 'topic3',
#  ('Uncle_SamCoco', 'WarReporter1'): 'topic0',
#  ('WarReporter1', 'Uncle_SamCoco'): 'topic3',
#  ('WhiteCat_7', 'mobi_ayubi'): 'topic2',
#  ('Witness_alHaqq', 'WarReporter1'): 'topic3',
#  ('YazeedDhardaa25', 'RamiAlLolah'): 'topic4',
#  ('_IshfaqAhmad', 'Nidalgazaui'): 'topic3',
#  ('__alfresco__', 'WarReporter1'): 'topic4',
#  ('abdlrhmn15', 'RamiAlLolah'): 'topic3',
#  ('abuayisha102', '432Mryam'): 'topic2',
#  ('abuayisha108', 'WarReporter1'): 'topic0',
#  ('abuhanzalah10', 'RamiAlLolah'): 'topic3',
#  ('abuhumayra4', 'MilkSheikh2'): 'topic0',
#  ('abutariq040', 'DawlaWitness11'): 'topic0',
#  ('abutariq041', 'emran_getu'): 'topic1',
#  ('al_nusra', 'al_nusra'): 'topic2',
#  ('alamreeki4', 'RamiAlLolah'): 'topic2',
#  ('ansarakhilafa', 'mustafaklash56'): 'topic2',
#  ('baaqiya_01', 'mustafaklash56'): 'topic1',
#  ('btt_ar', 'btt_ar'): 'topic1',
#  ('darulhijrateyni', 'MaghrebiQM'): 'topic4',
#  ('dieinurage29__7', 'baaqiya_01'): 'topic1',
#  ('fahadslay614', 'fahadslay614'): 'topic2',
#  ('freelance_112', 'freelance_112'): 'topic2',
#  ('grezz10', 'RamiAlLolah'): 'topic4',
#  ('ismailmahsud', 'ismailmahsud'): 'topic1',
#  ('kIakishini5', 'freelance_112'): 'topic2',
#  ('klakishinki', 'RamiAlLolah'): 'topic3',
#  ('ks48a174031', 'RamiAlLolah'): 'topic3',
#  ('lNSlDEWAR', 'RamiAlLolah'): 'topic3',
#  ('maisaraghereeb', 'maisaraghereeb'): 'topic3',
#  ('melvynlion', 'melvynlion'): 'topic0',
#  ('mobi_ayubi', 'warrnews'): 'topic4',
#  ('moustiklash', '_IshfaqAhmad'): 'topic1',
#  ('murasil1', 'WarReporter1'): 'topic3',
#  ('mustafaklash56', 'mustafaklash56'): 'topic0',
#  ('mustaklash', 'RamiAlLolah'): 'topic3',
#  ('ro34th', 'Uncle_SamCoco'): 'topic0',
#  ('safiyaimback', 'Nidalgazaui'): 'topic2',
#  ('safiyaimback', 'warrnews'): 'topic2',
#  ('saifulakhir', 'Nidalgazaui'): 'topic4',
#  ('sonofshishan', '__alfresco__'): 'topic0',
#  ('st3erer', 'AbuMusab_110'): 'topic3',
#  ('thefIamesofhaqq', 'MaghrebiHD'): 'topic2',
#  ('war_analysis', 'saifulakhir'): 'topic2',
#  ('warreporter2', 'RamiAlLolah'): 'topic3',
#  ('warrnews', 'Nidalgazaui'): 'topic4',
#  ('warrnews', 'RamiAlLolah'): 'topic4',
#  ('wayf44rerr', 'AbuMusab_110'): 'topic3',
#  ('wayyf44rer', 'RamiAlLolah'): 'topic4'}

# %% [markdown]
# ## Perform Network Analysis

# %%
import networkx as nx

# %%
# create an undirected graph
graph = nx.Graph()

# create an undirected graph
d_graph = nx.DiGraph()

# %%
# add edges to graph
graph.add_edges_from(edges)

# add edges to directed graph
d_graph.add_edges_from(edges)

# %%
print "# of profiles: ", graph.number_of_nodes()
print "# of connections: ", graph.number_of_edges()
# Out:
# # of profiles:  90
# # of connections:  86

# %%
# draw graph
import matplotlib.pyplot as plt
nx.draw(graph)
plt.show()

# # ways of drawing the graph
# nx.draw_random(graph)
# nx.draw_circular(graph)
# nx.draw_spectral(graph)

# %%
nodes = graph.nodes()

# %% [markdown]
# #### Create the exact same graph as integer values

# %%
# # convert nodes and edges to integer values 
# import numpy as np
# from sklearn import preprocessing

# le = preprocessing.LabelEncoder()

# # usernames
# le.fit(usernames)
# usernames_int = le.transform(usernames) 
# # convert numpy array to list
# usernames_int = usernames_int.tolist()

# # usernames
# le.fit(tagged_profiles)
# tagged_profiles_int = le.transform(tagged_profiles) 
# # convert numpy array to list
# tagged_profiles_int = tagged_profiles_int.tolist()

# %% [markdown]
# ## Analyse network

# %% [markdown]
# ### Analyse important members of network
#
# One way to define "importance" is the individual's betweenness centrality. The betweenness centrality is a measure of how many shortest paths pass through a particular vertex. The more shortest paths that pass through the vertex, the more central the vertex is to the network.
#
# The following approach computes the betweenness centrality of each vertex in the network using a parallelized algorithm.
#
# *Source:* https://blog.dominodatalab.com/social-network-analysis-with-networkx/

# %%
import networkx as nx
from multiprocessing import Pool
import itertools
import matplotlib.pyplot as plt
 
def partitions(nodes, n):
    "Partitions the nodes into n subsets"
    nodes_iter = iter(nodes)
    while True:
        partition = tuple(itertools.islice(nodes_iter,n))
        if not partition:
            return
        yield partition

def btwn_pool(G_tuple):
    return nx.betweenness_centrality_source(*G_tuple)
 

def between_parallel(G, processes = None):
    p = Pool(processes=processes)
    part_generator = 4*len(p._pool)
    node_partitions = list(partitions(G.nodes(), int(len(G)/part_generator)))
    num_partitions = len(node_partitions)

    bet_map = p.map(btwn_pool,
                    zip([G]*num_partitions,
                        [True]*num_partitions,
                        [None]*num_partitions,
                        node_partitions))
 
    bt_c = bet_map[0]
    for bt in bet_map[1:]:
        for n in bt:
            bt_c[n] += bt[n]
    return bt_c
 

# Runs the parallel betweenness algorithm on the network and plots the "top" vertices
def plotBetweeness(G_fb, top = 10):
 
    bt = between_parallel(G_fb)

    max_nodes =  sorted(bt.iteritems(), key = lambda v: -v[1])[:top]
    bt_values = [5]*len(G_fb.nodes())
    bt_colors = [0]*len(G_fb.nodes())
    for max_key, max_val in max_nodes:
        bt_values[max_key] = 150
        bt_colors[max_key] = 2

    plt.axis("off")
    nx.draw_networkx(G_fb, cmap = plt.get_cmap("rainbow"), node_color = bt_colors, node_size = bt_values, with_labels = False)
    plt.savefig("Twitter_ISIS_data/Between_network.png", format="PNG")
    plt.show()
    
plotBetweeness(graph)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-fe4bd2fc471f> in <module>()
#      53     plt.show()
#      54
# ---> 55 plotBetweeness(graph)
#
# <ipython-input-69-fe4bd2fc471f> in plotBetweeness(G_fb, top)
#      45     bt_colors = [0]*len(G_fb.nodes())
#      46     for max_key, max_val in max_nodes:
# ---> 47         bt_values[max_key] = 150
#      48         bt_colors[max_key] = 2
#      49
#
# TypeError: list indices must be integers, not str

# %% [markdown]
# ### Community Detection
#
# The criteria for finding good communities is similar to that for finding good clusters. We want to maximize intra-community edges while minimizing inter-community edges. Formally, the algorithm tries to maximize the modularity of network, or the fraction of edges that fall within the community minus the expected fraction of edges if the edges were distributed by random. Good communities should have a high number of intra-community edges, so by maximizing the modularity, we detect dense communities that have a high fraction of intra-community edges.
#
# *Source:* https://blog.dominodatalab.com/social-network-analysis-with-networkx/

# %%
import networkx as nx
import matplotlib.pyplot as plt
import community
 
def detectCommunities(G):
 
    parts = community.best_partition(G)
    values = [parts.get(node) for node in G.nodes()]

    plt.axis("off")
    nx.draw_networkx(G, cmap = plt.get_cmap("jet"), node_color = values, node_size = 35, with_labels = False)
    plt.savefig("Twitter_ISIS_data/communities.png", format = "PNG")
    plt.show()
    
detectCommunities(graph)

# %% [markdown]
# ### Analyse importancy of profiles

# %%
# find k-clique communities in graph 
# return the members of a clique of 7 members

list(nx.k_clique_communities(graph, 7))
# Out:
# [frozenset({'NaseemAhmed50',
#             'Nidalgazaui',
#             'RamiAlLolah',
#             'Uncle_SamCoco',
#             'WarReporter1',
#             'mobi_ayubi',
#             'warrnews'})]

# %%
# find the maximal number of cliques in this graph
nx.graph_number_of_cliques(graph)
# Out:
# 148

# %%
# return the clique number (size of the largest clique) for this graph
nx.graph_clique_number(graph)
# Out:
# 7

# %%
# Return the size of the largest maximal clique containing each given node.
size_of_largest_clique_per_node = nx.node_clique_number(graph)
# print size_of_largest_clique_per_node

# return only those profiles that are a member of clique that is larger than 6 members
profiles_of_large_cliques_dict = {k:v for (k,v) in size_of_largest_clique_per_node.items() if v > 6}
profiles_of_large_cliques_dict
# Out:
# {'NaseemAhmed50': 7,
#  'Nidalgazaui': 7,
#  'RamiAlLolah': 7,
#  'Uncle_SamCoco': 7,
#  'WarReporter1': 7,
#  'mobi_ayubi': 7,
#  'warrnews': 7}

# %%
# return a list of the profiles that are a member of cliques that are larger than 7 members
profiles_of_large_cliques = profiles_of_large_cliques_dict.keys()
profiles_of_large_cliques
# Out:
# ['Uncle_SamCoco',
#  'WarReporter1',
#  'RamiAlLolah',
#  'Nidalgazaui',
#  'mobi_ayubi',
#  'warrnews',
#  'NaseemAhmed50']

# %%
# Return the number of maximal cliques for each node.
number_of_cliques_per_node = nx.number_of_cliques(graph)

# return only those profiles that are a member of more than 5 different cliques
number_of_more_then_5_cliques_per_node = {k:v for (k,v) in number_of_cliques_per_node.items() if v > 5}
number_of_more_then_5_cliques_per_node
# Out:
# {'AbuNaseeha_03': 6,
#  'EPlC24': 7,
#  'FidaeeFulaani': 6,
#  'Freedom_speech2': 13,
#  'IbnKashmir_': 6,
#  'Jazrawi_Joulan': 9,
#  'Jazrawi_Saraqib': 9,
#  'MaghrabiArabi': 16,
#  'MaghrebiHD': 7,
#  'MaghrebiQM': 9,
#  'MilkSheikh2': 8,
#  'NaseemAhmed50': 6,
#  'Nidalgazaui': 40,
#  'QassamiMarwan': 7,
#  'RamiAlLolah': 62,
#  'Uncle_SamCoco': 25,
#  'WarReporter1': 33,
#  '_IshfaqAhmad': 6,
#  '__alfresco__': 16,
#  'mobi_ayubi': 17,
#  'warrnews': 16,
#  'wayf44rerr': 8}

# %% [markdown]
# Some accounts are a member of many different cliques.
#
# *How many of these accounts are active accounts?*

# %%
print len([account for account in number_of_more_then_5_cliques_per_node.keys() if account in passive_accounts])
# Out:
# 0

# %% [markdown]
# None of the accounts that are part of a large clique are passive accounts. This means that cliques only consist of active users.

# %%
# Return a list of cliques containing the given node.
members_of_clique_per_node = nx.cliques_containing_node(graph)
members_of_clique_per_node
# Out:
# {'04_8_1437': [['04_8_1437']],
#  '06230550_IS': [['MaghrebiHD', '06230550_IS'],
#   ['06230550_IS', 'pleaoftheummah']],
#  '1515Ummah': [['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah', 'mustaklash', '1515Ummah']],
#  '1Dawlah_III': [['1Dawlah_III', 'AbuNaseeha_03'],
#   ['1Dawlah_III', 'Alwala_bara']],
#  '432Mryam': [['abuayisha102', '432Mryam']],
#  'AbdusMujahid149': [['AbdusMujahid149']],
#  'AbuMusab_110': [['wayf44rerr',
#    '__alfresco__',
#    'Uncle_SamCoco',
#    'AbuMusab_110',
#    'st3erer'],
#   ['freelance_112', '__alfresco__', 'AbuMusab_110'],
#   ['freelance_112', 'kIakishini5', 'AbuMusab_110'],
#   ['kIakishini5', 'st3erer', 'AbuMusab_110']],
#  'AbuNaseeha_03': [['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah', 'abuhumayra4', 'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'AbuNaseeha_03'],
#   ['QassamiMarwan', 'abuhumayra4', 'AbuNaseeha_03'],
#   ['1Dawlah_III', 'AbuNaseeha_03']],
#  'Abu_Azzzam25': [['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['bintraveller', 'Abu_Azzzam25']],
#  'Abu_Ibn_Taha': [['Abu_Ibn_Taha', 'Uncle_SamCoco'],
#   ['Abu_Ibn_Taha', 'Baqiyah_Khilafa']],
#  'Afriqqiya_252': [['Suspend_Me_fags', 'Afriqqiya_252']],
#  'Al_Battar_Engl': [['Al_Battar_Engl']],
#  'Alwala_bara': [['RamiAlLolah', 'Nidalgazaui', '_IshfaqAhmad', 'Alwala_bara'],
#   ['QassamiMarwan', 'Nidalgazaui', 'Alwala_bara', '_IshfaqAhmad'],
#   ['1Dawlah_III', 'Alwala_bara']],
#  'AsimAbuMerjem': [['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'AsimAbuMerjem'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'AsimAbuMerjem'],
#   ['MilkSheikh2', 'Nidalgazaui', 'AsimAbuMerjem']],
#  'Bajwa47online': [['RamiAlLolah', 'Bajwa47online', 'NaseemAhmed50']],
#  'Baqiyah_Khilafa': [['RamiAlLolah', 'Nidalgazaui', 'Baqiyah_Khilafa'],
#   ['RamiAlLolah', 'alamreeki4', 'Baqiyah_Khilafa'],
#   ['Jazrawi_Joulan', 'Baqiyah_Khilafa'],
#   ['Abu_Ibn_Taha', 'Baqiyah_Khilafa']],
#  'Battar_English': [['Battar_English']],
#  'BilalIbnRabah1': [['BilalIbnRabah1', 'Nidalgazaui', 'MilkSheikh2'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'WarReporter1']],
#  'CXaafada2': [['CXaafada2', 'abuhumayra4']],
#  'DabiqsweetsMan': [['RamiAlLolah', 'DabiqsweetsMan']],
#  'DawlaWitness11': [['abutariq040', 'DawlaWitness11'],
#   ['DawlaWitness11', 'MaghrebiWM'],
#   ['DawlaWitness11', 'NaseemAhmed50']],
#  'Dieinurage308': [['Dieinurage308']],
#  'EPlC24': [['MaghrebiHD', 'thefIamesofhaqq', 'Jazrawi_Joulan', 'EPlC24'],
#   ['MaghrebiHD', 'Freedom_speech2', 'IbnKashmir_', 'EPlC24'],
#   ['MaghrebiHD',
#    'Freedom_speech2',
#    'Jazrawi_Joulan',
#    'MaghrabiArabi',
#    'EPlC24'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'MaghrabiArabi'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'thefIamesofhaqq'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'Freedom_speech2']],
#  'FidaeeFulaani': [['RamiAlLolah', 'Witness_alHaqq', 'FidaeeFulaani'],
#   ['RamiAlLolah', 'ks48a174031', 'FidaeeFulaani'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'mustaklash'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'MaghrabiArabi'],
#   ['MilkSheikh2', 'moustiklash', 'FidaeeFulaani'],
#   ['mustafaklash56', 'FidaeeFulaani']],
#  'Fidaee_Fulaani': [['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah', 'abuhumayra4', 'Fidaee_Fulaani']],
#  'Freedom_speech2': [['MaghrebiHD',
#    'Freedom_speech2',
#    'IbnKashmir_',
#    'EPlC24'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Jazrawi_Joulan', 'mobi_ayubi'],
#   ['MaghrebiHD',
#    'Freedom_speech2',
#    'Jazrawi_Joulan',
#    'MaghrabiArabi',
#    'EPlC24'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'MaghrabiArabi'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'Freedom_speech2']],
#  'IbnKashmir_': [['MaghrebiHD', 'Freedom_speech2', 'IbnKashmir_', 'EPlC24'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1']],
#  'Jazrawi_Joulan': [['MaghrebiHD',
#    'thefIamesofhaqq',
#    'Jazrawi_Joulan',
#    'EPlC24'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Jazrawi_Joulan', 'mobi_ayubi'],
#   ['MaghrebiHD',
#    'Freedom_speech2',
#    'Jazrawi_Joulan',
#    'MaghrabiArabi',
#    'EPlC24'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'thefIamesofhaqq'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews'],
#   ['Jazrawi_Joulan', 'Baqiyah_Khilafa'],
#   ['Jazrawi_Joulan', 'warrnews', 'MaghrabiArabi']],
#  'Jazrawi_Saraqib': [['wayf44rerr', 'mobi_ayubi', 'Jazrawi_Saraqib'],
#   ['wayf44rerr', '__alfresco__', 'Jazrawi_Saraqib'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'AsimAbuMerjem'],
#   ['abutariq040', 'WarReporter1', 'Jazrawi_Saraqib'],
#   ['safiyaimback', 'WarReporter1', 'Jazrawi_Saraqib']],
#  'JohnsonsBot': [['RamiAlLolah', 'Witness_alHaqq', 'JohnsonsBot']],
#  'JoinISNation102': [['RamiAlLolah', 'Nidalgazaui', 'JoinISNation102']],
#  'MaghrabiArabi': [['MaghrebiHD',
#    'Freedom_speech2',
#    'Uncle_SamCoco',
#    'MaghrabiArabi'],
#   ['MaghrebiHD',
#    'Freedom_speech2',
#    'Jazrawi_Joulan',
#    'MaghrabiArabi',
#    'EPlC24'],
#   ['ansarakhilafa', 'MaghrabiArabi'],
#   ['ManKhalfahum', 'MaghrabiArabi'],
#   ['MaghrebiQ', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'MaghrabiArabi'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'MaghrabiArabi'],
#   ['kIakishini5', 'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'MaghrabiArabi'],
#   ['Jazrawi_Joulan', 'warrnews', 'MaghrabiArabi']],
#  'MaghrebiHD': [['MaghrebiHD', '06230550_IS'],
#   ['MaghrebiHD', 'thefIamesofhaqq', 'Jazrawi_Joulan', 'EPlC24'],
#   ['MaghrebiHD', 'Freedom_speech2', 'IbnKashmir_', 'EPlC24'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Jazrawi_Joulan', 'mobi_ayubi'],
#   ['MaghrebiHD',
#    'Freedom_speech2',
#    'Jazrawi_Joulan',
#    'MaghrabiArabi',
#    'EPlC24']],
#  'MaghrebiQ': [['MaghrebiQ', 'MaghrabiArabi']],
#  'MaghrebiQM': [['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'AbuNaseeha_03'],
#   ['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    '_IshfaqAhmad',
#    'darulhijrateyni']],
#  'MaghrebiWM': [['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'MaghrabiArabi'],
#   ['DawlaWitness11', 'MaghrebiWM']],
#  'ManKhalfahum': [['ManKhalfahum', 'grezz10', 'mustaklash'],
#   ['ManKhalfahum', 'MaghrabiArabi']],
#  'MilkSheikh2': [['BilalIbnRabah1', 'Nidalgazaui', 'MilkSheikh2'],
#   ['MilkSheikh2', 'Nidalgazaui', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'Nidalgazaui', 'AsimAbuMerjem'],
#   ['MilkSheikh2', 'Nidalgazaui', '_IshfaqAhmad'],
#   ['MilkSheikh2', 'moustiklash', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'moustiklash', 'abuhumayra4'],
#   ['MilkSheikh2', 'moustiklash', 'FidaeeFulaani'],
#   ['MilkSheikh2', 'moustiklash', '_IshfaqAhmad']],
#  'Mosul_05': [['abutariq040', 'Mosul_05']],
#  'Mountainjjoool': [['freelance_112', '__alfresco__', 'Mountainjjoool'],
#   ['RamiAlLolah', 'Mountainjjoool', '__alfresco__', 'WarReporter1'],
#   ['wayff44rer', 'Mountainjjoool'],
#   ['nvor85j', 'Mountainjjoool']],
#  'NaseemAhmed50': [['RamiAlLolah', 'Bajwa47online', 'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['QassamiMarwan', 'Nidalgazaui', 'NaseemAhmed50', 'darulhijrateyni'],
#   ['DawlaWitness11', 'NaseemAhmed50']],
#  'Nidalgazaui': [['Suspend_Me_fags', 'Nidalgazaui', 'safiyaimback'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'MilkSheikh2'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'WarReporter1'],
#   ['saifulakhir', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah', 'Nidalgazaui', 'sonofshishan', '__alfresco__'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'Nidalgazaui', '_IshfaqAhmad', 'Alwala_bara'],
#   ['RamiAlLolah', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah', 'Nidalgazaui', 'Baqiyah_Khilafa'],
#   ['RamiAlLolah', 'Nidalgazaui', 'JoinISNation102'],
#   ['MilkSheikh2', 'Nidalgazaui', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'Nidalgazaui', 'AsimAbuMerjem'],
#   ['MilkSheikh2', 'Nidalgazaui', '_IshfaqAhmad'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'AbuNaseeha_03'],
#   ['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    '_IshfaqAhmad',
#    'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'NaseemAhmed50', 'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'Alwala_bara', '_IshfaqAhmad'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews']],
#  'QassamiMarwan': [['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'AbuNaseeha_03'],
#   ['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    '_IshfaqAhmad',
#    'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'NaseemAhmed50', 'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'Alwala_bara', '_IshfaqAhmad'],
#   ['QassamiMarwan', 'abdlrhmn15'],
#   ['QassamiMarwan', 'abuhumayra4', 'AbuNaseeha_03']],
#  'RamiAlLolah': [['RamiAlLolah',
#    'murasil1',
#    '__alfresco__',
#    'WarReporter1',
#    'warrnews'],
#   ['RamiAlLolah', 'grezz10', 'mustaklash'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'maisaraghereeb'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'WarReporter1'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'JohnsonsBot'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'FidaeeFulaani'],
#   ['RamiAlLolah', 'ks48a174031', 'FidaeeFulaani'],
#   ['RamiAlLolah', 'Bajwa47online', 'NaseemAhmed50'],
#   ['RamiAlLolah', 'klakishinki', 'WarReporter1'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'mustaklash'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah', 'Nidalgazaui', 'sonofshishan', '__alfresco__'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'Nidalgazaui', '_IshfaqAhmad', 'Alwala_bara'],
#   ['RamiAlLolah', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah', 'Nidalgazaui', 'Baqiyah_Khilafa'],
#   ['RamiAlLolah', 'Nidalgazaui', 'JoinISNation102'],
#   ['RamiAlLolah', 'abuhumayra4', 'AbuNaseeha_03'],
#   ['RamiAlLolah', 'abuhumayra4', 'Fidaee_Fulaani'],
#   ['RamiAlLolah', 'wayyf44rer', 'mobi_ayubi'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah', 'warreporter2'],
#   ['RamiAlLolah', 'DabiqsweetsMan'],
#   ['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah', 'WhiteCat_7', 'mobi_ayubi'],
#   ['RamiAlLolah', 'YazeedDhardaa25'],
#   ['RamiAlLolah', 'mustaklash', '1515Ummah'],
#   ['RamiAlLolah', 'thefIamesofhaqq', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah', 'abuhanzalah10'],
#   ['RamiAlLolah', 'abdlrhmn15'],
#   ['RamiAlLolah', 'melvynlion', 'WarReporter1'],
#   ['RamiAlLolah', 'melvynlion', 'sonofshishan'],
#   ['RamiAlLolah', 'Mountainjjoool', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah', 'alamreeki4', 'Baqiyah_Khilafa']],
#  'Suspend_Me_fags': [['Suspend_Me_fags', 'Nidalgazaui', 'safiyaimback'],
#   ['Suspend_Me_fags', 'Afriqqiya_252']],
#  'Uncle_SamCoco': [['MaghrebiHD',
#    'Freedom_speech2',
#    'Uncle_SamCoco',
#    'mobi_ayubi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'AbuMusab_110', 'st3erer'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'warrnews'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['MilkSheikh2', 'Nidalgazaui', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'moustiklash', 'Uncle_SamCoco'],
#   ['moustiklash', 'WarReporter1', 'Uncle_SamCoco'],
#   ['Abu_Ibn_Taha', 'Uncle_SamCoco']],
#  'WarReporter1': [['abuayisha108', 'WarReporter1'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'WarReporter1'],
#   ['RamiAlLolah', 'murasil1', '__alfresco__', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'WarReporter1'],
#   ['RamiAlLolah', 'klakishinki', 'WarReporter1'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah', 'thefIamesofhaqq', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah', 'melvynlion', 'WarReporter1'],
#   ['RamiAlLolah', 'Mountainjjoool', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['abutariq040', 'WarReporter1', 'Jazrawi_Saraqib'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'thefIamesofhaqq'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'Freedom_speech2'],
#   ['moustiklash', 'WarReporter1', 'Uncle_SamCoco'],
#   ['mustafaklash56', 'WarReporter1'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews'],
#   ['safiyaimback', 'WarReporter1', 'Jazrawi_Saraqib']],
#  'WhiteCat_7': [['RamiAlLolah', 'WhiteCat_7', 'mobi_ayubi']],
#  'Witness_alHaqq': [['RamiAlLolah', 'Witness_alHaqq', 'WarReporter1'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'JohnsonsBot'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'FidaeeFulaani']],
#  'YazeedDhardaa25': [['RamiAlLolah', 'YazeedDhardaa25']],
#  '_IshfaqAhmad': [['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah', 'Nidalgazaui', '_IshfaqAhmad', 'Alwala_bara'],
#   ['MilkSheikh2', 'Nidalgazaui', '_IshfaqAhmad'],
#   ['MilkSheikh2', 'moustiklash', '_IshfaqAhmad'],
#   ['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    '_IshfaqAhmad',
#    'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'Alwala_bara', '_IshfaqAhmad']],
#  '__alfresco__': [['wayf44rerr', '__alfresco__', 'murasil1', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'AbuMusab_110', 'st3erer'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Jazrawi_Saraqib'],
#   ['wayf44rerr', '__alfresco__', 'sonofshishan'],
#   ['freelance_112', '__alfresco__', 'murasil1'],
#   ['freelance_112', '__alfresco__', 'Mountainjjoool'],
#   ['freelance_112', '__alfresco__', 'AbuMusab_110'],
#   ['RamiAlLolah', 'murasil1', '__alfresco__', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah', 'Nidalgazaui', 'sonofshishan', '__alfresco__'],
#   ['RamiAlLolah', 'thefIamesofhaqq', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah', 'Mountainjjoool', '__alfresco__', 'WarReporter1']],
#  'abdlrhmn15': [['RamiAlLolah', 'abdlrhmn15'],
#   ['QassamiMarwan', 'abdlrhmn15']],
#  'abuayisha102': [['abuayisha102', '432Mryam']],
#  'abuayisha108': [['abuayisha108', 'WarReporter1'],
#   ['abuayisha108', 'squadsquaaaaad']],
#  'abuhanzalah10': [['RamiAlLolah', 'abuhanzalah10']],
#  'abuhumayra4': [['CXaafada2', 'abuhumayra4'],
#   ['RamiAlLolah', 'abuhumayra4', 'AbuNaseeha_03'],
#   ['RamiAlLolah', 'abuhumayra4', 'Fidaee_Fulaani'],
#   ['MilkSheikh2', 'moustiklash', 'abuhumayra4'],
#   ['QassamiMarwan', 'abuhumayra4', 'AbuNaseeha_03']],
#  'abutariq040': [['abutariq040', 'WarReporter1', 'Jazrawi_Saraqib'],
#   ['abutariq040', 'Mosul_05'],
#   ['abutariq040', 'DawlaWitness11']],
#  'abutariq041': [['emran_getu', 'abutariq041', 'war_analysis']],
#  'al_nusra': [['al_nusra']],
#  'alamreeki4': [['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah', 'alamreeki4', 'Baqiyah_Khilafa']],
#  'ansarakhilafa': [['ansarakhilafa', 'MaghrabiArabi'],
#   ['ansarakhilafa', 'mustafaklash56']],
#  'baaqiya_01': [['baaqiya_01', 'mustafaklash56'],
#   ['baaqiya_01', 'dieinurage29__7']],
#  'bintraveller': [['bintraveller', 'Abu_Azzzam25']],
#  'btt_ar': [['btt_ar']],
#  'darulhijrateyni': [['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    '_IshfaqAhmad',
#    'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'NaseemAhmed50', 'darulhijrateyni']],
#  'dieinurage29__7': [['baaqiya_01', 'dieinurage29__7']],
#  'emran_getu': [['emran_getu', 'abutariq041', 'war_analysis']],
#  'fahadslay614': [['fahadslay614']],
#  'freelance_112': [['freelance_112', '__alfresco__', 'murasil1'],
#   ['freelance_112', '__alfresco__', 'Mountainjjoool'],
#   ['freelance_112', '__alfresco__', 'AbuMusab_110'],
#   ['freelance_112', 'kIakishini5', 'AbuMusab_110']],
#  'grezz10': [['ManKhalfahum', 'grezz10', 'mustaklash'],
#   ['RamiAlLolah', 'grezz10', 'mustaklash']],
#  'ismailmahsud': [['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'MaghrabiArabi']],
#  'kIakishini5': [['freelance_112', 'kIakishini5', 'AbuMusab_110'],
#   ['kIakishini5', 'MaghrabiArabi'],
#   ['kIakishini5', 'st3erer', 'AbuMusab_110']],
#  'klakishinki': [['RamiAlLolah', 'klakishinki', 'WarReporter1']],
#  'ks48a174031': [['RamiAlLolah', 'ks48a174031', 'FidaeeFulaani']],
#  'lNSlDEWAR': [['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR']],
#  'maisaraghereeb': [['RamiAlLolah', 'maisaraghereeb']],
#  'melvynlion': [['wayf44rerr', 'melvynlion', 'sonofshishan'],
#   ['RamiAlLolah', 'melvynlion', 'WarReporter1'],
#   ['RamiAlLolah', 'melvynlion', 'sonofshishan']],
#  'mobi_ayubi': [['MaghrebiHD',
#    'Freedom_speech2',
#    'Uncle_SamCoco',
#    'mobi_ayubi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Jazrawi_Joulan', 'mobi_ayubi'],
#   ['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', 'mobi_ayubi', 'Jazrawi_Saraqib'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'wayyf44rer', 'mobi_ayubi'],
#   ['RamiAlLolah', 'WhiteCat_7', 'mobi_ayubi'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews']],
#  'moustiklash': [['MilkSheikh2', 'moustiklash', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'moustiklash', 'abuhumayra4'],
#   ['MilkSheikh2', 'moustiklash', 'FidaeeFulaani'],
#   ['MilkSheikh2', 'moustiklash', '_IshfaqAhmad'],
#   ['moustiklash', 'WarReporter1', 'Uncle_SamCoco']],
#  'murasil1': [['wayf44rerr', '__alfresco__', 'murasil1', 'warrnews'],
#   ['freelance_112', '__alfresco__', 'murasil1'],
#   ['RamiAlLolah', 'murasil1', '__alfresco__', 'WarReporter1', 'warrnews']],
#  'mustafaklash56': [['baaqiya_01', 'mustafaklash56'],
#   ['ansarakhilafa', 'mustafaklash56'],
#   ['mustafaklash56', 'WarReporter1'],
#   ['mustafaklash56', 'FidaeeFulaani']],
#  'mustaklash': [['ManKhalfahum', 'grezz10', 'mustaklash'],
#   ['RamiAlLolah', 'grezz10', 'mustaklash'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'mustaklash'],
#   ['RamiAlLolah', 'mustaklash', '1515Ummah']],
#  'nvor85j': [['nvor85j', 'Mountainjjoool']],
#  'pleaoftheummah': [['06230550_IS', 'pleaoftheummah']],
#  'ro34th': [['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'AsimAbuMerjem']],
#  'safiyaimback': [['Suspend_Me_fags', 'Nidalgazaui', 'safiyaimback'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews'],
#   ['safiyaimback', 'WarReporter1', 'Jazrawi_Saraqib']],
#  'saifulakhir': [['saifulakhir', 'Nidalgazaui', 'war_analysis']],
#  'sonofshishan': [['wayf44rerr', 'melvynlion', 'sonofshishan'],
#   ['wayf44rerr', '__alfresco__', 'sonofshishan'],
#   ['RamiAlLolah', 'Nidalgazaui', 'sonofshishan', '__alfresco__'],
#   ['RamiAlLolah', 'melvynlion', 'sonofshishan']],
#  'squadsquaaaaad': [['abuayisha108', 'squadsquaaaaad']],
#  'st3erer': [['wayf44rerr',
#    '__alfresco__',
#    'Uncle_SamCoco',
#    'AbuMusab_110',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['kIakishini5', 'st3erer', 'AbuMusab_110']],
#  'thefIamesofhaqq': [['MaghrebiHD',
#    'thefIamesofhaqq',
#    'Jazrawi_Joulan',
#    'EPlC24'],
#   ['RamiAlLolah', 'thefIamesofhaqq', '__alfresco__', 'WarReporter1'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'thefIamesofhaqq']],
#  'war_analysis': [['emran_getu', 'abutariq041', 'war_analysis'],
#   ['saifulakhir', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah', 'Nidalgazaui', 'war_analysis']],
#  'warreporter2': [['RamiAlLolah', 'warreporter2']],
#  'warrnews': [['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'murasil1', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'warrnews'],
#   ['RamiAlLolah', 'murasil1', '__alfresco__', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews'],
#   ['Jazrawi_Joulan', 'warrnews', 'MaghrabiArabi'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews']],
#  'wayf44rerr': [['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', 'mobi_ayubi', 'Jazrawi_Saraqib'],
#   ['wayf44rerr', 'melvynlion', 'sonofshishan'],
#   ['wayf44rerr', '__alfresco__', 'murasil1', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'AbuMusab_110', 'st3erer'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Jazrawi_Saraqib'],
#   ['wayf44rerr', '__alfresco__', 'sonofshishan']],
#  'wayff44rer': [['wayff44rer', 'Mountainjjoool']],
#  'wayyf44rer': [['RamiAlLolah', 'wayyf44rer', 'mobi_ayubi']]}

# %%
# return only those members of a clique who are a member of a clique that is larger than 6 members 
# look at profiles_of_large_cliques

members_of_large_cliques = dict((key,value) for key,value in members_of_clique_per_node.iteritems() if key in profiles_of_large_cliques)
members_of_large_cliques
# Out:
# {'NaseemAhmed50': [['RamiAlLolah', 'Bajwa47online', 'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['QassamiMarwan', 'Nidalgazaui', 'NaseemAhmed50', 'darulhijrateyni'],
#   ['DawlaWitness11', 'NaseemAhmed50']],
#  'Nidalgazaui': [['Suspend_Me_fags', 'Nidalgazaui', 'safiyaimback'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'MilkSheikh2'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'WarReporter1'],
#   ['saifulakhir', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah', 'Nidalgazaui', 'sonofshishan', '__alfresco__'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'Nidalgazaui', '_IshfaqAhmad', 'Alwala_bara'],
#   ['RamiAlLolah', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah', 'Nidalgazaui', 'Baqiyah_Khilafa'],
#   ['RamiAlLolah', 'Nidalgazaui', 'JoinISNation102'],
#   ['MilkSheikh2', 'Nidalgazaui', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'Nidalgazaui', 'AsimAbuMerjem'],
#   ['MilkSheikh2', 'Nidalgazaui', '_IshfaqAhmad'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'MaghrabiArabi'],
#   ['QassamiMarwan', 'Nidalgazaui', 'MaghrebiQM', 'AbuNaseeha_03'],
#   ['QassamiMarwan',
#    'Nidalgazaui',
#    'MaghrebiQM',
#    '_IshfaqAhmad',
#    'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'NaseemAhmed50', 'darulhijrateyni'],
#   ['QassamiMarwan', 'Nidalgazaui', 'Alwala_bara', '_IshfaqAhmad'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews']],
#  'RamiAlLolah': [['RamiAlLolah',
#    'murasil1',
#    '__alfresco__',
#    'WarReporter1',
#    'warrnews'],
#   ['RamiAlLolah', 'grezz10', 'mustaklash'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'maisaraghereeb'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'WarReporter1'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'JohnsonsBot'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'FidaeeFulaani'],
#   ['RamiAlLolah', 'ks48a174031', 'FidaeeFulaani'],
#   ['RamiAlLolah', 'Bajwa47online', 'NaseemAhmed50'],
#   ['RamiAlLolah', 'klakishinki', 'WarReporter1'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'mustaklash'],
#   ['RamiAlLolah', 'FidaeeFulaani', 'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah', 'Nidalgazaui', 'sonofshishan', '__alfresco__'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'MaghrabiArabi'],
#   ['RamiAlLolah', 'Nidalgazaui', '_IshfaqAhmad', 'Alwala_bara'],
#   ['RamiAlLolah', 'Nidalgazaui', 'war_analysis'],
#   ['RamiAlLolah', 'Nidalgazaui', 'Baqiyah_Khilafa'],
#   ['RamiAlLolah', 'Nidalgazaui', 'JoinISNation102'],
#   ['RamiAlLolah', 'abuhumayra4', 'AbuNaseeha_03'],
#   ['RamiAlLolah', 'abuhumayra4', 'Fidaee_Fulaani'],
#   ['RamiAlLolah', 'wayyf44rer', 'mobi_ayubi'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah', 'warreporter2'],
#   ['RamiAlLolah', 'DabiqsweetsMan'],
#   ['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah', 'WhiteCat_7', 'mobi_ayubi'],
#   ['RamiAlLolah', 'YazeedDhardaa25'],
#   ['RamiAlLolah', 'mustaklash', '1515Ummah'],
#   ['RamiAlLolah', 'thefIamesofhaqq', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah', 'abuhanzalah10'],
#   ['RamiAlLolah', 'abdlrhmn15'],
#   ['RamiAlLolah', 'melvynlion', 'WarReporter1'],
#   ['RamiAlLolah', 'melvynlion', 'sonofshishan'],
#   ['RamiAlLolah', 'Mountainjjoool', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah', 'alamreeki4', 'Baqiyah_Khilafa']],
#  'Uncle_SamCoco': [['MaghrebiHD',
#    'Freedom_speech2',
#    'Uncle_SamCoco',
#    'mobi_ayubi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'AbuMusab_110', 'st3erer'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'warrnews'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    'MaghrebiQM'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'Fidaee_Fulaani',
#    '1515Ummah'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrabiArabi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah',
#    'Abu_Azzzam25',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'AbuNaseeha_03'],
#   ['MilkSheikh2', 'Nidalgazaui', 'Uncle_SamCoco'],
#   ['MilkSheikh2', 'moustiklash', 'Uncle_SamCoco'],
#   ['moustiklash', 'WarReporter1', 'Uncle_SamCoco'],
#   ['Abu_Ibn_Taha', 'Uncle_SamCoco']],
#  'WarReporter1': [['abuayisha108', 'WarReporter1'],
#   ['BilalIbnRabah1', 'Nidalgazaui', 'WarReporter1'],
#   ['RamiAlLolah', 'murasil1', '__alfresco__', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'Witness_alHaqq', 'WarReporter1'],
#   ['RamiAlLolah', 'klakishinki', 'WarReporter1'],
#   ['RamiAlLolah',
#    'Jazrawi_Saraqib',
#    'WarReporter1',
#    'IbnKashmir_',
#    '__alfresco__'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'st3erer'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'Uncle_SamCoco'],
#   ['RamiAlLolah', 'ro34th', 'WarReporter1', 'AsimAbuMerjem'],
#   ['RamiAlLolah', 'thefIamesofhaqq', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah', 'melvynlion', 'WarReporter1'],
#   ['RamiAlLolah', 'Mountainjjoool', '__alfresco__', 'WarReporter1'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['abutariq040', 'WarReporter1', 'Jazrawi_Saraqib'],
#   ['EPlC24', 'Nidalgazaui', 'Freedom_speech2', 'IbnKashmir_', 'WarReporter1'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'thefIamesofhaqq'],
#   ['EPlC24', 'WarReporter1', 'Jazrawi_Joulan', 'Freedom_speech2'],
#   ['moustiklash', 'WarReporter1', 'Uncle_SamCoco'],
#   ['mustafaklash56', 'WarReporter1'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews'],
#   ['safiyaimback', 'WarReporter1', 'Jazrawi_Saraqib']],
#  'mobi_ayubi': [['MaghrebiHD',
#    'Freedom_speech2',
#    'Uncle_SamCoco',
#    'mobi_ayubi'],
#   ['MaghrebiHD', 'Freedom_speech2', 'Jazrawi_Joulan', 'mobi_ayubi'],
#   ['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', 'mobi_ayubi', 'Jazrawi_Saraqib'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Uncle_SamCoco', 'mobi_ayubi'],
#   ['RamiAlLolah', 'MaghrebiWM', 'Jazrawi_Saraqib', 'mobi_ayubi'],
#   ['RamiAlLolah', 'Jazrawi_Saraqib', 'WarReporter1', 'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'Freedom_speech2'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'lNSlDEWAR'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah', 'Nidalgazaui', 'ismailmahsud', 'mobi_ayubi'],
#   ['RamiAlLolah', 'wayyf44rer', 'mobi_ayubi'],
#   ['RamiAlLolah', 'WhiteCat_7', 'mobi_ayubi'],
#   ['RamiAlLolah',
#    'alamreeki4',
#    'mobi_ayubi',
#    'WarReporter1',
#    'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'Freedom_speech2'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews']],
#  'warrnews': [['wayf44rerr', 'mobi_ayubi', 'Uncle_SamCoco', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'murasil1', 'warrnews'],
#   ['wayf44rerr', '__alfresco__', 'Uncle_SamCoco', 'warrnews'],
#   ['RamiAlLolah', 'murasil1', '__alfresco__', 'WarReporter1', 'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    '__alfresco__'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'IbnKashmir_',
#    'WarReporter1',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    'mobi_ayubi',
#    'NaseemAhmed50',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'WarReporter1',
#    '__alfresco__',
#    'warrnews'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'mobi_ayubi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'Uncle_SamCoco',
#    'MaghrebiQM',
#    'warrnews',
#    'MaghrabiArabi'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'MaghrebiQM',
#    '_IshfaqAhmad'],
#   ['RamiAlLolah',
#    'Nidalgazaui',
#    'darulhijrateyni',
#    'warrnews',
#    'NaseemAhmed50'],
#   ['RamiAlLolah', 'Nidalgazaui', 'AsimAbuMerjem', 'WarReporter1', 'warrnews'],
#   ['Jazrawi_Joulan', 'WarReporter1', 'mobi_ayubi', 'warrnews'],
#   ['Jazrawi_Joulan', 'warrnews', 'MaghrabiArabi'],
#   ['safiyaimback', 'WarReporter1', 'Nidalgazaui', 'warrnews']]}

# %%
# # return only the names of the members of a clique that is larger than 7 members
# for key,value in members_of_large_cliques.iteritems():
#     for clique in value:
#         if len(clique) > 7:
#             print {key: clique}
            
# for key, value in members_of_large_cliques.items():
#     for clique in value:
#         if len(clique) > 7:
#             print clique

# %% [markdown]
# #### Get number of connections per user

# %%
degree = nx.degree(graph)
print '# of profiles with connections in undirected graph: ', len(degree.keys())
print degree
print '---'
degree_d_graph = nx.degree(d_graph)
print '# of profiles with connections in directed graph: ', len(degree_d_graph.keys())
print degree_d_graph
# Out:
# # of profiles with connections in undirected graph:  98
# {'murasil1': 6, 'Suspend_Me_fags': 5, 'Uncle_SamCoco': 26, 'maisaraghereeb': 3, '432Mryam': 1, 'Witness_alHaqq': 4, 'ismailmahsud': 6, 'ks48a174031': 2, 'MaghrebiQ': 1, 'Afriqqiya_252': 3, 'wayf44rerr': 12, 'freelance_112': 7, 'Nidalgazaui': 34, 'ro34th': 4, 'MilkSheikh2': 8, '_IshfaqAhmad': 9, '__alfresco__': 15, 'Fidaee_Fulaani': 8, 'WhiteCat_7': 2, 'squadsquaaaaad': 1, 'abuhanzalah10': 1, 'melvynlion': 6, '1Dawlah_III': 2, 'Jazrawi_Joulan': 11, 'Mountainjjoool': 6, 'al_nusra': 2, 'nvor85j': 1, 'pleaoftheummah': 1, 'st3erer': 10, 'emran_getu': 2, 'MaghrebiWM': 6, 'fahadslay614': 2, 'darulhijrateyni': 7, 'Bajwa47online': 4, 'AbdusMujahid149': 2, 'klakishinki': 2, 'Jazrawi_Saraqib': 11, 'Freedom_speech2': 11, 'abuhumayra4': 7, 'wayyf44rer': 2, '04_8_1437': 2, 'moustiklash': 6, 'CXaafada2': 1, 'FidaeeFulaani': 10, 'Al_Battar_Engl': 2, 'YazeedDhardaa25': 3, 'QassamiMarwan': 10, 'JoinISNation102': 4, 'Abu_Ibn_Taha': 2, 'AbuMusab_110': 8, 'Baqiyah_Khilafa': 7, '1515Ummah': 5, 'Alwala_bara': 5, 'MaghrebiHD': 9, 'warreporter2': 1, 'DabiqsweetsMan': 3, 'sonofshishan': 5, 'MaghrebiQM': 12, '06230550_IS': 2, 'saifulakhir': 2, 'Battar_English': 2, 'JohnsonsBot': 2, 'abutariq041': 2, 'ManKhalfahum': 3, 'abutariq040': 4, 'IbnKashmir_': 12, 'Abu_Azzzam25': 7, 'mustaklash': 7, 'thefIamesofhaqq': 8, 'war_analysis': 5, 'mobi_ayubi': 18, 'abdlrhmn15': 2, 'bintraveller': 1, 'Mosul_05': 1, 'safiyaimback': 5, 'DawlaWitness11': 3, 'alamreeki4': 5, 'grezz10': 3, 'baaqiya_01': 4, 'abuayisha108': 2, 'EPlC24': 10, 'btt_ar': 2, 'abuayisha102': 1, 'MaghrabiArabi': 21, 'NaseemAhmed50': 13, 'RamiAlLolah': 53, 'BilalIbnRabah1': 3, 'lNSlDEWAR': 8, 'ansarakhilafa': 2, 'dieinurage29__7': 1, 'WarReporter1': 31, 'kIakishini5': 4, 'AsimAbuMerjem': 7, 'AbuNaseeha_03': 10, 'warrnews': 19, 'mustafaklash56': 6, 'Dieinurage308': 2, 'wayff44rer': 1}
# ---
# # of profiles with connections in directed graph:  98
# {'murasil1': 7, 'Suspend_Me_fags': 5, 'Uncle_SamCoco': 31, 'maisaraghereeb': 3, '432Mryam': 2, 'Witness_alHaqq': 4, 'ismailmahsud': 6, 'ks48a174031': 2, 'MaghrebiQ': 1, 'Afriqqiya_252': 3, 'wayf44rerr': 15, 'freelance_112': 7, 'Nidalgazaui': 35, 'ro34th': 4, 'MilkSheikh2': 10, '_IshfaqAhmad': 9, '__alfresco__': 19, 'Fidaee_Fulaani': 8, 'WhiteCat_7': 2, 'squadsquaaaaad': 1, 'abuhanzalah10': 1, 'melvynlion': 6, '1Dawlah_III': 2, 'Jazrawi_Joulan': 11, 'Mountainjjoool': 6, 'al_nusra': 2, 'nvor85j': 1, 'pleaoftheummah': 1, 'st3erer': 13, 'emran_getu': 2, 'MaghrebiWM': 7, 'fahadslay614': 2, 'darulhijrateyni': 7, 'Bajwa47online': 4, 'AbdusMujahid149': 2, 'klakishinki': 3, 'Jazrawi_Saraqib': 12, 'Freedom_speech2': 11, 'abuhumayra4': 8, 'wayyf44rer': 2, '04_8_1437': 2, 'moustiklash': 7, 'CXaafada2': 1, 'FidaeeFulaani': 12, 'Al_Battar_Engl': 2, 'YazeedDhardaa25': 3, 'QassamiMarwan': 12, 'JoinISNation102': 4, 'Abu_Ibn_Taha': 2, 'AbuMusab_110': 8, 'Baqiyah_Khilafa': 7, '1515Ummah': 6, 'Alwala_bara': 5, 'MaghrebiHD': 9, 'warreporter2': 1, 'DabiqsweetsMan': 3, 'sonofshishan': 5, 'MaghrebiQM': 13, '06230550_IS': 2, 'saifulakhir': 2, 'Battar_English': 2, 'JohnsonsBot': 2, 'abutariq041': 2, 'ManKhalfahum': 3, 'abutariq040': 4, 'IbnKashmir_': 12, 'Abu_Azzzam25': 7, 'mustaklash': 7, 'thefIamesofhaqq': 10, 'war_analysis': 5, 'mobi_ayubi': 18, 'abdlrhmn15': 2, 'bintraveller': 1, 'Mosul_05': 1, 'safiyaimback': 5, 'DawlaWitness11': 3, 'alamreeki4': 5, 'grezz10': 3, 'baaqiya_01': 4, 'abuayisha108': 2, 'EPlC24': 11, 'btt_ar': 2, 'abuayisha102': 2, 'MaghrabiArabi': 24, 'NaseemAhmed50': 14, 'RamiAlLolah': 55, 'BilalIbnRabah1': 3, 'lNSlDEWAR': 8, 'ansarakhilafa': 3, 'dieinurage29__7': 1, 'WarReporter1': 36, 'kIakishini5': 4, 'AsimAbuMerjem': 9, 'AbuNaseeha_03': 10, 'warrnews': 20, 'mustafaklash56': 6, 'Dieinurage308': 2, 'wayff44rer': 1}

# %% [markdown]
# #### Show the density of the graph

# %%
print 'density undirected graph: ', nx.density(graph)
# Out:
# density undirected graph:  0.0675362928677

# %% [markdown]
# This seems like a very low density. Which means that there are possibly many profiles that have only one connection

# %%
# show proportion of ingoig edges per profile
ingoing_edges = nx.in_degree_centrality(d_graph)
print 'ingoing edges per node: '
print ingoing_edges
print '---'

# return only those profiles that show a high proportion of the ingoing edges
{k:v for (k,v) in ingoing_edges.items() if v > 0.1}
# Out:
# ingoing edges per node:
# {'murasil1': 0.010309278350515464, 'Suspend_Me_fags': 0.020618556701030927, 'Uncle_SamCoco': 0.15463917525773196, 'maisaraghereeb': 0.010309278350515464, '432Mryam': 0.010309278350515464, 'Witness_alHaqq': 0.0, 'ismailmahsud': 0.030927835051546393, 'ks48a174031': 0.0, 'MaghrebiQ': 0.010309278350515464, 'Afriqqiya_252': 0.020618556701030927, 'wayf44rerr': 0.09278350515463918, 'freelance_112': 0.061855670103092786, 'Nidalgazaui': 0.3402061855670103, 'ro34th': 0.0, 'MilkSheikh2': 0.07216494845360824, '_IshfaqAhmad': 0.020618556701030927, '__alfresco__': 0.10309278350515463, 'Fidaee_Fulaani': 0.030927835051546393, 'WhiteCat_7': 0.0, 'squadsquaaaaad': 0.010309278350515464, 'abuhanzalah10': 0.0, 'melvynlion': 0.010309278350515464, '1Dawlah_III': 0.020618556701030927, 'Jazrawi_Joulan': 0.09278350515463918, 'Mountainjjoool': 0.0, 'al_nusra': 0.010309278350515464, 'nvor85j': 0.010309278350515464, 'pleaoftheummah': 0.010309278350515464, 'st3erer': 0.05154639175257732, 'emran_getu': 0.020618556701030927, 'MaghrebiWM': 0.05154639175257732, 'fahadslay614': 0.010309278350515464, 'darulhijrateyni': 0.010309278350515464, 'Bajwa47online': 0.010309278350515464, 'AbdusMujahid149': 0.010309278350515464, 'klakishinki': 0.010309278350515464, 'Jazrawi_Saraqib': 0.08247422680412371, 'Freedom_speech2': 0.061855670103092786, 'abuhumayra4': 0.010309278350515464, 'wayyf44rer': 0.010309278350515464, '04_8_1437': 0.010309278350515464, 'moustiklash': 0.020618556701030927, 'CXaafada2': 0.010309278350515464, 'FidaeeFulaani': 0.05154639175257732, 'Al_Battar_Engl': 0.010309278350515464, 'YazeedDhardaa25': 0.010309278350515464, 'QassamiMarwan': 0.09278350515463918, 'JoinISNation102': 0.010309278350515464, 'Abu_Ibn_Taha': 0.0, 'AbuMusab_110': 0.05154639175257732, 'Baqiyah_Khilafa': 0.030927835051546393, '1515Ummah': 0.010309278350515464, 'Alwala_bara': 0.010309278350515464, 'MaghrebiHD': 0.09278350515463918, 'warreporter2': 0.0, 'DabiqsweetsMan': 0.010309278350515464, 'sonofshishan': 0.010309278350515464, 'MaghrebiQM': 0.10309278350515463, '06230550_IS': 0.0, 'saifulakhir': 0.010309278350515464, 'Battar_English': 0.010309278350515464, 'JohnsonsBot': 0.010309278350515464, 'abutariq041': 0.010309278350515464, 'ManKhalfahum': 0.020618556701030927, 'abutariq040': 0.0, 'IbnKashmir_': 0.010309278350515464, 'Abu_Azzzam25': 0.010309278350515464, 'mustaklash': 0.05154639175257732, 'thefIamesofhaqq': 0.030927835051546393, 'war_analysis': 0.0, 'mobi_ayubi': 0.020618556701030927, 'abdlrhmn15': 0.0, 'bintraveller': 0.010309278350515464, 'Mosul_05': 0.010309278350515464, 'safiyaimback': 0.0, 'DawlaWitness11': 0.020618556701030927, 'alamreeki4': 0.0, 'grezz10': 0.0, 'baaqiya_01': 0.020618556701030927, 'abuayisha108': 0.0, 'EPlC24': 0.041237113402061855, 'btt_ar': 0.010309278350515464, 'abuayisha102': 0.010309278350515464, 'MaghrabiArabi': 0.041237113402061855, 'NaseemAhmed50': 0.061855670103092786, 'RamiAlLolah': 0.5257731958762887, 'BilalIbnRabah1': 0.0, 'lNSlDEWAR': 0.05154639175257732, 'ansarakhilafa': 0.010309278350515464, 'dieinurage29__7': 0.0, 'WarReporter1': 0.2268041237113402, 'kIakishini5': 0.020618556701030927, 'AsimAbuMerjem': 0.030927835051546393, 'AbuNaseeha_03': 0.041237113402061855, 'warrnews': 0.14432989690721648, 'mustafaklash56': 0.05154639175257732, 'Dieinurage308': 0.010309278350515464, 'wayff44rer': 0.010309278350515464}
# ---
# {'MaghrebiQM': 0.10309278350515463,
#  'Nidalgazaui': 0.3402061855670103,
#  'RamiAlLolah': 0.5257731958762887,
#  'Uncle_SamCoco': 0.15463917525773196,
#  'WarReporter1': 0.2268041237113402,
#  '__alfresco__': 0.10309278350515463,
#  'warrnews': 0.14432989690721648}

# %%
[account for account in {k:v for (k,v) in ingoing_edges.items() if v > 0.1}.keys() if account in active_accounts]
# Out:
# ['__alfresco__',
#  'Uncle_SamCoco',
#  'WarReporter1',
#  'RamiAlLolah',
#  'Nidalgazaui',
#  'MaghrebiQM',
#  'warrnews']

# %% [markdown]
# The profiles with many ingoing edges are still profiles of active accounts.

# %%
# show proportion of outgoing edges per profile
outgoing_edges = nx.out_degree_centrality(d_graph)
print 'outgoing edges per node: '
print outgoing_edges

# return only those profiles that show a high proportion of the outgoing edges
{k:v for (k,v) in outgoing_edges.items() if v > 0.1}
# Out:
# outgoing edges per node:
# {'murasil1': 0.061855670103092786, 'Suspend_Me_fags': 0.030927835051546393, 'Uncle_SamCoco': 0.16494845360824742, 'maisaraghereeb': 0.020618556701030927, '432Mryam': 0.010309278350515464, 'Witness_alHaqq': 0.041237113402061855, 'ismailmahsud': 0.030927835051546393, 'ks48a174031': 0.020618556701030927, 'MaghrebiQ': 0.0, 'Afriqqiya_252': 0.010309278350515464, 'wayf44rerr': 0.061855670103092786, 'freelance_112': 0.010309278350515464, 'Nidalgazaui': 0.020618556701030927, 'ro34th': 0.041237113402061855, 'MilkSheikh2': 0.030927835051546393, '_IshfaqAhmad': 0.07216494845360824, '__alfresco__': 0.09278350515463918, 'Fidaee_Fulaani': 0.05154639175257732, 'WhiteCat_7': 0.020618556701030927, 'squadsquaaaaad': 0.0, 'abuhanzalah10': 0.010309278350515464, 'melvynlion': 0.05154639175257732, '1Dawlah_III': 0.0, 'Jazrawi_Joulan': 0.020618556701030927, 'Mountainjjoool': 0.061855670103092786, 'al_nusra': 0.010309278350515464, 'nvor85j': 0.0, 'pleaoftheummah': 0.0, 'st3erer': 0.08247422680412371, 'emran_getu': 0.0, 'MaghrebiWM': 0.020618556701030927, 'fahadslay614': 0.010309278350515464, 'darulhijrateyni': 0.061855670103092786, 'Bajwa47online': 0.030927835051546393, 'AbdusMujahid149': 0.010309278350515464, 'klakishinki': 0.020618556701030927, 'Jazrawi_Saraqib': 0.041237113402061855, 'Freedom_speech2': 0.05154639175257732, 'abuhumayra4': 0.07216494845360824, 'wayyf44rer': 0.010309278350515464, '04_8_1437': 0.010309278350515464, 'moustiklash': 0.05154639175257732, 'CXaafada2': 0.0, 'FidaeeFulaani': 0.07216494845360824, 'Al_Battar_Engl': 0.010309278350515464, 'YazeedDhardaa25': 0.020618556701030927, 'QassamiMarwan': 0.030927835051546393, 'JoinISNation102': 0.030927835051546393, 'Abu_Ibn_Taha': 0.020618556701030927, 'AbuMusab_110': 0.030927835051546393, 'Baqiyah_Khilafa': 0.041237113402061855, '1515Ummah': 0.05154639175257732, 'Alwala_bara': 0.041237113402061855, 'MaghrebiHD': 0.0, 'warreporter2': 0.010309278350515464, 'DabiqsweetsMan': 0.020618556701030927, 'sonofshishan': 0.041237113402061855, 'MaghrebiQM': 0.030927835051546393, '06230550_IS': 0.020618556701030927, 'saifulakhir': 0.010309278350515464, 'Battar_English': 0.010309278350515464, 'JohnsonsBot': 0.010309278350515464, 'abutariq041': 0.010309278350515464, 'ManKhalfahum': 0.010309278350515464, 'abutariq040': 0.041237113402061855, 'IbnKashmir_': 0.1134020618556701, 'Abu_Azzzam25': 0.061855670103092786, 'mustaklash': 0.020618556701030927, 'thefIamesofhaqq': 0.07216494845360824, 'war_analysis': 0.05154639175257732, 'mobi_ayubi': 0.16494845360824742, 'abdlrhmn15': 0.020618556701030927, 'bintraveller': 0.0, 'Mosul_05': 0.0, 'safiyaimback': 0.05154639175257732, 'DawlaWitness11': 0.010309278350515464, 'alamreeki4': 0.05154639175257732, 'grezz10': 0.030927835051546393, 'baaqiya_01': 0.020618556701030927, 'abuayisha108': 0.020618556701030927, 'EPlC24': 0.07216494845360824, 'btt_ar': 0.010309278350515464, 'abuayisha102': 0.010309278350515464, 'MaghrabiArabi': 0.20618556701030927, 'NaseemAhmed50': 0.08247422680412371, 'RamiAlLolah': 0.041237113402061855, 'BilalIbnRabah1': 0.030927835051546393, 'lNSlDEWAR': 0.030927835051546393, 'ansarakhilafa': 0.020618556701030927, 'dieinurage29__7': 0.010309278350515464, 'WarReporter1': 0.14432989690721648, 'kIakishini5': 0.020618556701030927, 'AsimAbuMerjem': 0.061855670103092786, 'AbuNaseeha_03': 0.061855670103092786, 'warrnews': 0.061855670103092786, 'mustafaklash56': 0.010309278350515464, 'Dieinurage308': 0.010309278350515464, 'wayff44rer': 0.0}
# {'IbnKashmir_': 0.1134020618556701,
#  'MaghrabiArabi': 0.20618556701030927,
#  'Uncle_SamCoco': 0.16494845360824742,
#  'WarReporter1': 0.14432989690721648,
#  'mobi_ayubi': 0.16494845360824742}

# %% [markdown]
# While the accounts of RamiAlLolah and Nidalgazaui show many ingoing edges, proportions of 0.53 and 0.34 respectively, these profiles are not among the top tweeting profiles.
#
# In contrast, the account of MaghrabiArabi does not appear in the top receiving profiles, scores at the top of those accounts that show a high proportion of outgoing tweets.

# %% [markdown]
# #### Split profiles into two groups:
# - 1 group of those profiles who have more than 1 connection
# - 1 group of those profiles who have only 1 connection

# %%
print 'total # of profiles: ', len(degree.keys())
# Out:
# total # of profiles:  98

# %%
# get only the keys of which the value is > 1

profiles_with_multiple_connections = []
for k,v in degree.iteritems():
    if v > 1:
        profiles_with_multiple_connections.append(k)
        
print '# of profiles with multiple connections: ', len(profiles_with_multiple_connections)
print profiles_with_multiple_connections[:5]
# Out:
# # of profiles with multiple connections:  85
# ['murasil1', 'Suspend_Me_fags', 'Uncle_SamCoco', 'maisaraghereeb', 'Witness_alHaqq']

# %%
# get only the keys of which the value is = 1

profiles_with_one_connection = []
for k,v in degree.iteritems():
    if v == 1:
        profiles_with_one_connection.append(k)
        
print '# of profiles with only one connection: ', len(profiles_with_one_connection)
print profiles_with_one_connection[:5]
# Out:
# # of profiles with only one connection:  13
# ['432Mryam', 'MaghrebiQ', 'squadsquaaaaad', 'abuhanzalah10', 'nvor85j']

# %% [markdown]
# #### Analyse the number of occurences per connection

# %%
from collections import Counter
occurences_per_connection = Counter(edges)
occurences_per_connection
# Out:
# Counter({('04_8_1437', '04_8_1437'): 3,
#          ('06230550_IS', 'MaghrebiHD'): 1,
#          ('1515Ummah', 'mustaklash'): 1,
#          ('432Mryam', 'abuayisha102'): 1,
#          ('AbdusMujahid149', 'AbdusMujahid149'): 1,
#          ('AbuMusab_110', 'kIakishini5'): 1,
#          ('AbuNaseeha_03', 'MaghrebiQM'): 1,
#          ('Abu_Azzzam25', 'RamiAlLolah'): 1,
#          ('Abu_Ibn_Taha', 'Baqiyah_Khilafa'): 1,
#          ('Afriqqiya_252', 'Afriqqiya_252'): 4,
#          ('Al_Battar_Engl', 'Al_Battar_Engl'): 1,
#          ('Alwala_bara', 'RamiAlLolah'): 1,
#          ('AsimAbuMerjem', 'Nidalgazaui'): 1,
#          ('Bajwa47online', 'Bajwa47online'): 1,
#          ('Baqiyah_Khilafa', 'Jazrawi_Joulan'): 1,
#          ('Battar_English', 'Battar_English'): 1,
#          ('BilalIbnRabah1', 'Nidalgazaui'): 1,
#          ('DabiqsweetsMan', 'RamiAlLolah'): 1,
#          ('DawlaWitness11', 'MaghrebiWM'): 1,
#          ('Dieinurage308', 'Dieinurage308'): 4,
#          ('EPlC24', 'MaghrebiHD'): 1,
#          ('FidaeeFulaani', 'RamiAlLolah'): 1,
#          ('Fidaee_Fulaani', 'Fidaee_Fulaani'): 1,
#          ('Freedom_speech2', 'Jazrawi_Joulan'): 1,
#          ('IbnKashmir_', 'Jazrawi_Saraqib'): 1,
#          ('Jazrawi_Joulan', 'MaghrebiHD'): 1,
#          ('Jazrawi_Saraqib', 'MaghrebiWM'): 1,
#          ('JohnsonsBot', 'RamiAlLolah'): 1,
#          ('JoinISNation102', 'Nidalgazaui'): 1,
#          ('MaghrabiArabi', 'lNSlDEWAR'): 1,
#          ('MaghrebiQM', 'RamiAlLolah'): 1,
#          ('MaghrebiWM', 'RamiAlLolah'): 1,
#          ('ManKhalfahum', 'mustaklash'): 1,
#          ('MilkSheikh2', 'AsimAbuMerjem'): 1,
#          ('Mountainjjoool', 'nvor85j'): 1,
#          ('NaseemAhmed50', 'DawlaWitness11'): 1,
#          ('Nidalgazaui', 'warrnews'): 1,
#          ('QassamiMarwan', 'MaghrebiQM'): 1,
#          ('RamiAlLolah', 'Nidalgazaui'): 1,
#          ('Suspend_Me_fags', 'Suspend_Me_fags'): 1,
#          ('Uncle_SamCoco', 'WarReporter1'): 1,
#          ('WarReporter1', 'Uncle_SamCoco'): 1,
#          ('WhiteCat_7', 'mobi_ayubi'): 1,
#          ('Witness_alHaqq', 'WarReporter1'): 1,
#          ('YazeedDhardaa25', 'RamiAlLolah'): 1,
#          ('_IshfaqAhmad', 'Nidalgazaui'): 1,
#          ('__alfresco__', 'WarReporter1'): 1,
#          ('abdlrhmn15', 'RamiAlLolah'): 1,
#          ('abuayisha102', '432Mryam'): 1,
#          ('abuayisha108', 'WarReporter1'): 1,
#          ('abuhanzalah10', 'RamiAlLolah'): 1,
#          ('abuhumayra4', 'MilkSheikh2'): 1,
#          ('abutariq040', 'DawlaWitness11'): 1,
#          ('abutariq041', 'emran_getu'): 1,
#          ('al_nusra', 'al_nusra'): 1,
#          ('alamreeki4', 'RamiAlLolah'): 1,
#          ('ansarakhilafa', 'mustafaklash56'): 1,
#          ('baaqiya_01', 'mustafaklash56'): 1,
#          ('btt_ar', 'btt_ar'): 1,
#          ('darulhijrateyni', 'MaghrebiQM'): 1,
#          ('dieinurage29__7', 'baaqiya_01'): 1,
#          ('fahadslay614', 'fahadslay614'): 4,
#          ('freelance_112', 'freelance_112'): 1,
#          ('grezz10', 'RamiAlLolah'): 1,
#          ('ismailmahsud', 'ismailmahsud'): 1,
#          ('kIakishini5', 'freelance_112'): 2,
#          ('klakishinki', 'RamiAlLolah'): 1,
#          ('ks48a174031', 'RamiAlLolah'): 1,
#          ('lNSlDEWAR', 'RamiAlLolah'): 1,
#          ('maisaraghereeb', 'maisaraghereeb'): 1,
#          ('melvynlion', 'melvynlion'): 1,
#          ('mobi_ayubi', 'warrnews'): 1,
#          ('moustiklash', '_IshfaqAhmad'): 1,
#          ('murasil1', 'WarReporter1'): 1,
#          ('mustafaklash56', 'mustafaklash56'): 1,
#          ('mustaklash', 'RamiAlLolah'): 1,
#          ('ro34th', 'Uncle_SamCoco'): 1,
#          ('safiyaimback', 'Nidalgazaui'): 1,
#          ('safiyaimback', 'warrnews'): 1,
#          ('saifulakhir', 'Nidalgazaui'): 1,
#          ('sonofshishan', '__alfresco__'): 1,
#          ('st3erer', 'AbuMusab_110'): 1,
#          ('thefIamesofhaqq', 'MaghrebiHD'): 1,
#          ('war_analysis', 'saifulakhir'): 1,
#          ('warreporter2', 'RamiAlLolah'): 1,
#          ('warrnews', 'Nidalgazaui'): 1,
#          ('warrnews', 'RamiAlLolah'): 1,
#          ('wayf44rerr', 'AbuMusab_110'): 1,
#          ('wayyf44rer', 'RamiAlLolah'): 1})

# %% [markdown]
# In some cases a user sends a message to his own profile. This sounds as a remarkable thing to do.
# This could explain why some nodes don't seem to have a connection when the connections are represented as a graph.
#
# Even, in some cases a user has only one connection, which is his own profile, and sends multiple tweets to his own profile. For example:
#
#     ('Al_Battar_Engl', 'Al_Battar_Engl'): 20
#
# This could imply that either this person posts tweets to him self as a reminder, possibly a reminder of another tweet. Or multiple users are the owner of this profile and possibly collect retweets. This could still be explored in more detail.

# %% [markdown]
# ### Add the number of occurences per connection as an attribute to the edge

# %%
nx.set_edge_attributes(graph, 'occurences_per_connection_att', occurences_per_connection)
print 'example of # of occurences between AbuMusab_110 and freelance_112: ' 
graph['AbuMusab_110']['freelance_112']['occurences_per_connection_att']
# Out:
# example of # of occurences between AbuMusab_110 and freelance_112:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-d0ac8f889ffb> in <module>()
#       1 nx.set_edge_attributes(graph, 'occurences_per_connection_att', occurences_per_connection)
#       2 print 'example of # of occurences between AbuMusab_110 and freelance_112: '
# ----> 3 graph['AbuMusab_110']['freelance_112']['occurences_per_connection_att']
#
# KeyError: 'freelance_112'

# %% [markdown]
# ### Find the users that only send tweets to themselves

# %%
# return only those profiles that are a member of a clique that is smaller than 2 members
profiles_of_small_cliques = {k:v for (k,v) in size_of_largest_clique_per_node.items() if v < 2}
profiles_of_small_cliques
# Out:
# {'04_8_1437': 1,
#  'AbdusMujahid149': 1,
#  'Al_Battar_Engl': 1,
#  'Battar_English': 1,
#  'Dieinurage308': 1,
#  'al_nusra': 1,
#  'btt_ar': 1,
#  'fahadslay614': 1}

# %%
# return the connections of those profiles 

# return only those members of a clique who are a member of a clique that is smaller than 2 members 
dict((key,value) for key,value in members_of_clique_per_node.iteritems() if key in profiles_of_small_cliques)
# Out:
# {'04_8_1437': [['04_8_1437']],
#  'AbdusMujahid149': [['AbdusMujahid149']],
#  'Al_Battar_Engl': [['Al_Battar_Engl']],
#  'Battar_English': [['Battar_English']],
#  'Dieinurage308': [['Dieinurage308']],
#  'al_nusra': [['al_nusra']],
#  'btt_ar': [['btt_ar']],
#  'fahadslay614': [['fahadslay614']]}

# %%
# get the connections of one user with himself
identical_user_connection = [('04_8_1437', '04_8_1437'),
                             ('AbdusMujahid149', 'AbdusMujahid149'),
                             ('Al_Battar_Engl', 'Al_Battar_Engl'),
                             ('Battar_English', 'Battar_English'),
                             ('Dieinurage308', 'Dieinurage308'),
                             ('al_nusra', 'al_nusra'),
                             ('btt_ar', 'btt_ar'),
                             ('fahadslay614', 'fahadslay614')]

# %%
# get the number of times that a profile sends a tweet to his own account
for k,v in occurences_per_connection.iteritems():
    if k in identical_user_connection:
        print k,v
# Out:
# ('btt_ar', 'btt_ar') 13
# ('fahadslay614', 'fahadslay614') 10
# ('al_nusra', 'al_nusra') 1
# ('Dieinurage308', 'Dieinurage308') 4
# ('Al_Battar_Engl', 'Al_Battar_Engl') 20
# ('Battar_English', 'Battar_English') 18
# ('04_8_1437', '04_8_1437') 3
# ('AbdusMujahid149', 'AbdusMujahid149') 1

# %% [markdown]
# ### Find similarities between user names
#
# Some profile names are very similar to each other. In some cases only one letter has changed in comparison to another exising profile name.
# For example:
#
#     ('MaghrebiHD', 'MaghrebiQ')
#
# This could implicate that one and the same user is the owner of multiple profiles.
# In order to find the users that may tweet from multiple accounts, we will search for those profiles that are very similar to each other.
#
# I will use the Levenshtein distance to calculate the similarity between profile names.
# https://en.wikipedia.org/wiki/Levenshtein_distance#Computing_Levenshtein_distance

# %%
import Levenshtein

# %% [markdown]
# The algorythm counts the number of letters that are different between a pair of words.
# For example:
#
#     Levenshtein.distance('thisis', 'thisisnot')
#     = 3

# %%
# creat pairs of usernames
# output [(username1, username1), (username1, username2)]
import itertools
username_combinations = list(itertools.combinations(usernames, 2))

# %%
# get similarity between pairs of usernames
word_similarity = []
for username1, username2 in username_combinations:
    word_similarity.append(Levenshtein.distance(username1, username2))
    
username_similarity = zip(username_combinations, word_similarity)
username_similarity[:5]
# Out:
# [(('GunsandCoffee70', 'AbuLaythAlHindi'), 14),
#  (('GunsandCoffee70', 'YazeedDhardaa25'), 15),
#  (('GunsandCoffee70', 'abubakerdimshqi'), 14),
#  (('GunsandCoffee70', 'BaqiyaIs'), 14),
#  (('GunsandCoffee70', 'WhiteCat_7'), 13)]

# %%
# create keys for username_combinations
# create values for word_similarity list
username_similarity_dict = dict(username_similarity)

# %%
# retrieve usernames that are very similar to each other
{k:v for (k,v) in username_similarity_dict.items() if v < 5}
# Out:
# {('Fidaee_Fulaani', 'FidaeeFulaani'): 1,
#  ('MaghrebiHD', 'MaghrebiQ'): 2,
#  ('MaghrebiHD', 'MaghrebiWM'): 2,
#  ('MaghrebiQ', 'MaghrebiWM'): 2,
#  ('MaghrebiQM', 'MaghrebiHD'): 2,
#  ('MaghrebiQM', 'MaghrebiQ'): 1,
#  ('MaghrebiQM', 'MaghrebiWM'): 1,
#  ('Mosul_05', 'Abdul__05'): 4,
#  ('abuayisha102', 'abuayisha108'): 1,
#  ('abutariq040', 'abutariq041'): 1,
#  ('klakishinki', 'kIakishini5'): 3,
#  ('mustaklash', 'moustiklash'): 2,
#  ('mustaklash', 'mustafaklash56'): 4,
#  ('warreporter2', 'WarReporter1'): 3,
#  ('wayf44rerr', 'wayff44rer'): 2,
#  ('wayyf44rer', 'wayf44rerr'): 2,
#  ('wayyf44rer', 'wayff44rer'): 1}

# %% [markdown]
# It will be interesting to explore the impact on the degree density when the profile names that are very similar, are grouped to one profile name.

# %% [markdown]
# ### Add topic as attribute to edges

# %%
nx.set_edge_attributes(graph, 'tweettopic_per_connection_att', connection_topic)
print 'example of topic of tweet between wayyf44rer and  RamiAlLolah: ' 
graph['wayyf44rer']['RamiAlLolah']['tweettopic_per_connection_att']
# Out:
# example of topic of tweet between wayyf44rer and  RamiAlLolah:
# 'topic4'

# %%
# show all connections per topic
topic0 = [key for key,value in connection_topic.iteritems() if value =='topic3']
topic1 = [key for key,value in connection_topic.iteritems() if value =='topic3']
topic2 = [key for key,value in connection_topic.iteritems() if value =='topic3']
topic3 = [key for key,value in connection_topic.iteritems() if value =='topic3']
topic4 = [key for key,value in connection_topic.iteritems() if value =='topic4']

print '# connections with topic 0: ', len(topic0)
print '# connections with topic 1: ', len(topic1)
print '# connections with topic 2: ', len(topic2)
print '# connections with topic 3: ', len(topic3)
print '# connections with topic 4: ', len(topic4)
# Out:
#  # connections with topic 0:  22
# # connections with topic 1:  22
# # connections with topic 2:  22
# # connections with topic 3:  22
# # connections with topic 4:  16
